# %% [markdown]
# ### Scraper Script

# %% [markdown]
# This script is a stripped down version of the [Scraper.py](https://github.com/SarthakJShetty/Bias/blob/master/Scraper.py) code that is used to generate the dataset for analyses of research trends. It's a small piece of the larger [Bias](https://GitHub.com/SarthakJShetty/Bias) project.

# %% [markdown]
# ### 1.0 <u>Code</u>

# %% [markdown]
# Here we are importing the libraries required to run the scraping code. We are retrieving the abstacts, paper title and author names from [Springer](https://link.springer.com).

# %%
from urllib.request import urlopen
''''Importing urllib.error to handle errors in HTTP pinging.'''
import urllib.error
'''BeautifulSoup is used for souping.'''
from bs4 import BeautifulSoup
'''Counter generates a dictionary from the abstract data, providing frequencies of occurences'''
from collections import Counter
'''Importing the CSV library here to dump the dictionary for further analysis and error checking if required. Will edit it out later.'''
import csv
'''Importing datetime for logging of various function executions'''
from datetime import datetime
'''Importing numpy to generate a random integer for the delay_function (see below)'''
import numpy as np
'''This library is imported to check if we can feasibly introduce delays into the processor loop to reduce instances of the remote server, shutting the connection while scrapping extraordinarily large datasets.'''
import time
'''This library is imported to build the LOG folders and directories'''
import os

# %% [markdown]
# Declaring the ```keywords``` variable here, which is topic that the scrapping will take place on. It will be appended to the start and abstract URLs during retrival. Also defining the ```trend_keywords``` term here, whose frequency is to be studied using the trends chart.

# %%
keywords_to_search="Endemic Species Atlantic Forests"
keywords_to_search = keywords_to_search.split()
trend_keywords="Conservation"

# %% [markdown]
# From here, we define the functions that are responsible for pinging, retriving and storing the information and the meta-data collected from the Springer scrapping.

# %%
def pre_processing(keywords):
	'''This function contains all the pre-processing statements related to the running of the program, including:
	1. Default starter URL of the page to scrape.
	2. Default location of LOGS, including:
		1. Location of Abstract_ID_Database
		2. Location of Abstract_Database'''

	'''Declaring the time and date variables here. Year, month, day, hours, minute & seconds.'''
	run_start_year = str(datetime.now().date().year)
	run_start_month = str(datetime.now().date().month)
	run_start_day = str(datetime.now().date().day)
	run_start_date = str(datetime.now().date())
	run_start_hour = str(datetime.now().time().hour)
	run_start_minute = str(datetime.now().time().minute)
	run_start_second = str(datetime.now().time().second)
	'''Keywords have to be written into the filename of the LOG that we are running'''
	folder_attachement = ""
	if(len(keywords)==1):
		folder_attachement = keywords[0]
	else:
		for keyword_index in range(0, len(keywords)):
			if((keyword_index+1)==len(keywords)):
				folder_attachement = folder_attachement+keywords[keyword_index]
			else:
				folder_attachement = folder_attachement+keywords[keyword_index]+"_"
	'''Declaring the LOG folder and the abstract, abstract_id & status_logger files.'''
	logs_folder_name = "LOGS"+"/"+"LOG"+"_"+run_start_date+'_'+run_start_hour+'_'+run_start_minute+"_"+folder_attachement
	abstract_id_log_name =logs_folder_name+"/"+'Abstract_ID_Database'+'_'+run_start_date+'_'+run_start_hour+'_'+run_start_minute+"_"
	abstracts_log_name = logs_folder_name+"/"+'Abstract_Database'+'_'+run_start_date+'_'+run_start_hour+'_'+run_start_minute
	status_logger_name = logs_folder_name+"/"+'Status_Logger'+'_'+run_start_date+'_'+run_start_hour+'_'+run_start_minute

	'''If the filename does not exist create the file in the LOG directory'''
	if not os.path.exists(logs_folder_name):
		os.makedirs(logs_folder_name)
	
	'''Creating the status_log and writing the session duration & date'''
	status_log = open(status_logger_name+'.txt', 'a')
	status_log.write("Session:"+" "+run_start_day+"/"+run_start_month+"/"+run_start_year+"\n")
	status_log.write("Time:"+" "+run_start_hour+":"+run_start_minute+":"+run_start_second+"\n")
	status_log.close()

	logs_folder_name_status_key = "Built LOG folder for session"
	status_logger(status_logger_name, logs_folder_name_status_key)

	query_string = ""
	if (len(keywords)==1):
		query_string = keywords[0]
	else:
		for keyword_index in range(0, len(keywords)):
			if((keyword_index+1)==len(keywords)):
				query_string = query_string+keywords[keyword_index]
			else:
				query_string = query_string+keywords[keyword_index]+"+"

	start_url = "https://link.springer.com/search/page/"
	abstract_url = 'https://link.springer.com'

	return abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, logs_folder_name, status_logger_name

# %% [markdown]
# Defining the ```status_logger()``` function here which will log the functioning of all the individual modules. Primarily designed to improve diagnostics of the code once the scrapping has commenced.

# %%
def status_logger(status_logger_name, status_key):
	'''Status logger to print and log details throught the running the program.
	Declaring current_hour, current_minute & current_second.'''
	current_hour = str(datetime.now().time().hour)
	current_minute = str(datetime.now().time().minute)
	current_second = str(datetime.now().time().second)
	'''Logging the complete_status_key and printing the complete_status_key'''
	complete_status_key = "[INFO]"+current_hour+":"+current_minute+":"+current_second+" "+status_key
	print(complete_status_key)
	status_log = open(status_logger_name+'.txt', 'a')
	status_log.write(complete_status_key+"\n")
	status_log.close()

# %% [markdown]
# The ```pre_processing()``` function is responsible for setting up the fundamental files and variables required to get the scrapper up and running.

# %%
abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, logs_folder_name, status_logger_name = pre_processing(keywords_to_search)
# Out:
# [INFO]14:22:35 Built LOG folder for session

# %% [markdown]
# Beyond this block, the actual functions powering the script begin. Comments are provided at the beginning of each function to ensure readability and understanding.

# %%
def url_reader(url, status_logger_name):
	'''This keyword is supplied to the URL and is hence used for souping.
	Encountered an error where some links would not open due to HTTP.error
	This is added here to try and ping the page. If it returns false the loop ignores it and
	moves on to the next PII number'''
	try:
		page=urlopen(url)
		page_status(page, status_logger_name)
		return page
	except (UnboundLocalError, urllib.error.HTTPError):
		pass

def results_determiner(url, status_logger_name):
	'''This function determines the number of results that a particular keywords returns
	once it looks up the keyword on link.springer.com
	The function returns all the possible links containing results and then provides the total number of results
	returned by a particular keyword, or combination of keywords.'''
	first_page_to_scrape = urlopen(url)
	first_page_to_scrape_soup = BeautifulSoup(first_page_to_scrape, 'html.parser')
	number_of_results = first_page_to_scrape_soup.find('h1', {'id':'number-of-search-results-and-search-terms'}).find('strong').text

def url_generator(start_url, query_string, status_logger_name):
	'''This function is written to scrape all possible webpages of a given topic
	The search for the URLs truncates when determiner variable doesn't return a positive value'''
	'''Initiallizing a list here in order to contain the URLs. Even if a URL does not return valid results,
	it is popped later on from the list.'''
	urls_to_scrape=[]
	counter = 0
	total_url = start_url+str(counter)+"?facet-content-type=\"Article\"&query="+query_string
	initial_url_status_key = total_url+" "+"has been obtained"
	status_logger(status_logger_name, initial_url_status_key)
	urls_to_scrape.append(total_url)
	test_soup = BeautifulSoup(urlopen(total_url), 'html.parser')
	determiner = test_soup.find('a', {'class':'title'})
	'''This while loop continuously pings and checks for new webpages, then stores them for scraping'''
	while(determiner):
		counter = counter+1
		total_url = start_url+str(counter)+"?facet-content-type=\"Article\"&query="+query_string
		url_generator_while_status_key=total_url+" "+"has been obtained"
		status_logger(status_logger_name, url_generator_while_status_key)
		soup = BeautifulSoup(urlopen(total_url), 'html.parser')
		determiner = soup.find('a', {'class':'title'})
		urls_to_scrape.append(total_url)
	urls_to_scrape.pop(len(urls_to_scrape)-1)
	return urls_to_scrape

def page_status(page, status_logger_name):
	'''Prints the page status. Will be used whenever a new webpage is picked for scraping.'''
	page_status_key = "Page status:"+" "+str(page.status)
	status_logger(status_logger_name, page_status_key)

def page_souper(page, status_logger_name):
	'''Function soups the webpage elements and provided the tags for search.
	Note: Appropriate encoding has to be picked up beenfore souping'''
	page_souper_start_status_key = "Souping page"
	status_logger(status_logger_name, page_souper_start_status_key)
	page_soup = BeautifulSoup(page, 'html.parser')
	page_souper_stop_status_key = "Souped page"
	status_logger(status_logger_name, page_souper_stop_status_key)
	return page_soup

def abstract_word_extractor(abstract, abstract_title, abstract_year, permanent_word_sorter_list, trend_keywords, status_logger_name):
	'''This function creates the list that stores the text in the form of individual words
	against their year of appearence.'''
	abstract_word_sorter_start_status_key = "Adding:"+" "+abstract_title+" "+"to the archival list"
	status_logger(status_logger_name, abstract_word_sorter_start_status_key)
	'''This line of code converts the entire abstract into lower case'''
	abstract = abstract.lower()
	'''Converting the abstract into a list of words'''
	abstract_word_list = abstract.split()
	'''This line of code sorts the elements in the word list alphabetically. Working with dataframes is harden, hence
	we are curbing this issue by modifying the list rather.'''
	abstract_word_list.sort()
	'''If the word currently being looped in the abstract list matches the trend word being investigated for, the year it appears
	is appended to the permanent word sorter list'''
	for element in abstract_word_list:
		if(element==trend_keywords[0]):
			permanent_word_sorter_list.append(abstract_year[:4])

	abstract_word_sorter_end_status_key = "Added:"+" "+abstract_title+" "+"to the archival list"
	status_logger(status_logger_name, abstract_word_sorter_end_status_key)

def abstract_year_list_post_processor(permanent_word_sorter_list, status_logger_name):
	'''Because of this function we have a dictionary containing the frequency of occurrence of terms in specific years'''
	abstract_year_list_post_processor_start_status_key = "Post processing of permanent word sorter list has commenced"
	status_logger(status_logger_name, abstract_year_list_post_processor_start_status_key)

	starting_year = min(permanent_word_sorter_list)
	ending_year = max(permanent_word_sorter_list)

	abstract_year_dictionary = Counter(permanent_word_sorter_list)

	abstract_year_list_post_processor_end_status_key = "Post processing of permanent word sorter list has completed"
	status_logger(status_logger_name, abstract_year_list_post_processor_end_status_key)

	return abstract_year_dictionary, starting_year, ending_year

def abstract_year_dictionary_dumper(abstract_word_dictionary, abstracts_log_name, status_logger_name):
	'''This function saves the abstract word dumper to the disc for further inspection.
	The file is saved as a CSV bucket and then dumped.'''
	permanent_word_sorter_list_start_status_key = "Dumping the entire dictionary to the disc"
	status_logger(status_logger_name, permanent_word_sorter_list_start_status_key)
	with open(abstracts_log_name+"_"+"DICTIONARY.csv", 'w') as dictionary_to_csv:
		writer = csv.writer(dictionary_to_csv)
		for key, value in abstract_word_dictionary.items():
			year = key
			writer.writerow([year, value])
	
	permanent_word_sorter_list_end_status_key = "Dumped the entire dictionary to the disc"
	status_logger(status_logger_name, permanent_word_sorter_list_end_status_key)
		
def abstract_page_scraper(abstract_url, abstract_input_tag_id, abstracts_log_name, permanent_word_sorter_list, trend_keywords, site_url_index, status_logger_name):
	'''This function is written to scrape the actual abstract of the specific paper,
	 that is being referenced within the list of abstracts'''
	abstract_page_scraper_status_key="Abstract ID:"+" "+abstract_input_tag_id
	status_logger(status_logger_name, abstract_page_scraper_status_key)
	abstract_page_url = abstract_url+abstract_input_tag_id
	abstract_page = url_reader(abstract_page_url, status_logger_name)
	abstract_soup = page_souper(abstract_page, status_logger_name)
	title = title_scraper(abstract_soup, status_logger_name)
	abstract_date = abstract_date_scraper(title, abstract_soup, status_logger_name)

	'''Due to repeated attribute errors with respect to scraping the authors name, these failsafes had to be put in place.'''
	try:
		author = author_scraper(abstract_soup, status_logger_name)
	except AttributeError:
		author = "Author not available"

	'''Due to repeated attribute errors with respect to scraping the abstract, these failsafes had to be put in place.'''
	try:
		abstract = abstract_scraper(abstract_soup)
		abstract_word_extractor(abstract, title, abstract_date, permanent_word_sorter_list, trend_keywords, status_logger_name)
	except AttributeError:
		abstract = "Abstract not available"

	abstract_database_writer(abstract_page_url, title, author, abstract, abstracts_log_name, abstract_date, status_logger_name)
	analytical_abstract_database_writer(title, author, abstract, abstracts_log_name, status_logger_name)

def abstract_crawler(abstract_url, abstract_id_log_name, abstracts_log_name, permanent_word_sorter_list, trend_keywords, site_url_index, status_logger_name):
	abstract_crawler_temp_index  = site_url_index
	'''This function crawls the page and access each and every abstract'''
	abstract_input_tag_ids = abstract_id_database_reader(abstract_id_log_name, abstract_crawler_temp_index, status_logger_name)
	for abstract_input_tag_id in abstract_input_tag_ids:
		try:
			abstract_crawler_accept_status_key="Abstract Number:"+" "+str((abstract_input_tag_ids.index(abstract_input_tag_id)+1)+abstract_crawler_temp_index*20)
			status_logger(status_logger_name, abstract_crawler_accept_status_key)
			abstract_page_scraper(abstract_url, abstract_input_tag_id, abstracts_log_name, permanent_word_sorter_list, trend_keywords, site_url_index, status_logger_name)
			'''Introduces a 5 second delay between successive pings.'''
			delay_function(status_logger_name)
		except TypeError:
			abstract_crawler_reject_status_key="Abstract Number:"+" "+str(abstract_input_tag_ids.index(abstract_input_tag_id)+1)+" "+"could not be processed"
			status_logger(status_logger_name, abstract_crawler_reject_status_key)
			pass

def analytical_abstract_database_writer(title, author, abstract, abstracts_log_name, status_logger_name):
	'''This function will generate a secondary abstract file that will contain only the abstract.
	The  abstract file generated will be passed onto the Visualizer and Analyzer function, as opposed to the complete 
	abstract log file containing lot of garbage words in addition to the abstract text.'''
	analytical_abstract_database_writer_start_status_key = "Writing"+" "+title+" "+"by"+" "+author+" "+"to analytical abstracts file"
	status_logger(status_logger_name, analytical_abstract_database_writer_start_status_key)

	analytical_abstracts_txt_log = open(abstracts_log_name+'_'+'ANALYTICAL'+'.txt', 'a')
	analytical_abstracts_txt_log.write(abstract)
	analytical_abstracts_txt_log.write('\n'+'\n')
	analytical_abstracts_txt_log.close()

	analytical_abstract_database_writer_stop_status_key = "Written"+" "+title+" "+"to disc"
	status_logger(status_logger_name, analytical_abstract_database_writer_stop_status_key)

def abstract_database_writer(abstract_page_url, title, author, abstract, abstracts_log_name, abstract_date, status_logger_name):
	'''This function makes text files to contain the abstracts for future reference.
	It holds: 1) Title, 2) Author(s), 3) Abstract'''
	abstract_database_writer_start_status_key = "Writing"+" "+title+" "+"by"+" "+author+" "+"to disc"
	status_logger(status_logger_name, abstract_database_writer_start_status_key)
	abstracts_csv_log = open(abstracts_log_name+'.csv', 'a')
	abstracts_txt_log = open(abstracts_log_name+'.txt', 'a')
	abstracts_txt_log.write("Title:"+" "+title)
	abstracts_txt_log.write('\n')
	abstracts_txt_log.write("Author:"+" "+author)
	abstracts_txt_log.write('\n')
	abstracts_txt_log.write("Date:"+" "+abstract_date)
	abstracts_txt_log.write('\n')
	abstracts_txt_log.write("URL:"+" "+abstract_page_url)
	abstracts_txt_log.write('\n')
	abstracts_txt_log.write("Abstract:"+" "+abstract)
	abstracts_csv_log.write(abstract)
	abstracts_csv_log.write('\n')
	abstracts_txt_log.write('\n'+'\n')
	abstracts_txt_log.close()
	abstracts_csv_log.close()
	abstract_database_writer_stop_status_key = "Written"+" "+title+" "+"to disc"
	status_logger(status_logger_name, abstract_database_writer_stop_status_key)

def abstract_id_database_reader(abstract_id_log_name, site_url_index, status_logger_name):
	'''This function has been explicitly written to access
	the abstracts database that the given prgram generates.'''
	abstract_id_reader_temp_index = site_url_index
	abstract_id_database_reader_start_status_key = "Extracting Abstract IDs from disc"
	status_logger(status_logger_name, abstract_id_database_reader_start_status_key)

	lines_in_abstract_id_database=[line.rstrip('\n') for line in open(abstract_id_log_name+str(abstract_id_reader_temp_index+1)+'.txt')]

	abstract_id_database_reader_stop_status_key = "Extracted Abstract IDs from disc"
	status_logger(status_logger_name, abstract_id_database_reader_stop_status_key)

	return lines_in_abstract_id_database

def abstract_id_database_writer(abstract_id_log_name, abstract_input_tag_id, site_url_index):
	'''This function writes the abtract ids to a .txt file for easy access and documentation.'''
	abstract_id_writer_temp_index  = site_url_index
	abstract_id_log = open((abstract_id_log_name+str(abstract_id_writer_temp_index+1)+'.txt'), 'a')
	abstract_id_log.write(abstract_input_tag_id)
	abstract_id_log.write('\n')
	abstract_id_log.close()

def abstract_date_scraper(title, abstract_soup, status_logger_name):
	'''This function scrapes the date associated with each of the abstracts.
	This function will play a crucial role in the functionality that we are trying to build into our project.'''
	date_scraper_entry_status_key = "Scraping date of the abstract titled:"+" "+title
	status_logger(status_logger_name, date_scraper_entry_status_key)
	try:
		abstract_date = abstract_soup.find('time').get('datetime')
		date_scraper_exit_status_key = title+" "+"was published on"+" "+abstract_date
	except AttributeError:
		abstract_date = "Date for abstract titled:"+" "+title+" "+"was not available"
		date_scraper_exit_status_key = abstract_date
		pass
	
	status_logger(status_logger_name, date_scraper_exit_status_key)
	return abstract_date

def abstract_scraper(abstract_soup):
	'''This function scrapes the abstract from the soup and returns to the page scraper'''
	try:
		abstract = str(abstract_soup.find('p', {'id':'Par1'}).text.encode('utf-8'))[1:]
	except AttributeError:
		abstract = str(abstract_soup.find('p', {'class':'Para'}).text.encode('utf-8'))[1:]
	return abstract

def author_scraper(abstract_soup, status_logger_name):
	'''This function scrapes the author of the text, for easy navigation and search'''
	author_scraper_start_status_key = "Scraping the author name"
	status_logger(status_logger_name, author_scraper_start_status_key)
	author = str(abstract_soup.find('span', {'class':'authors__name'}).text.encode('utf-8'))[1:]
	author_scraper_end_status_key = "Scraped the author name"
	status_logger(status_logger_name, author_scraper_end_status_key)
	return author

def title_scraper(abstract_soup, status_logger_name):
	'''This function scrapes the title of the text'''
	title_scraper_start_status_key = "Scraping the title of the abstract"
	status_logger(status_logger_name, title_scraper_start_status_key)
	try:
		title = str(abstract_soup.find('h1',{'class':'ArticleTitle'}).text.encode('utf-8'))[1:]
	except AttributeError:
		title = str(abstract_soup.find('h1',{'class':'ChapterTitle'}).text.encode('utf-8'))[1:]
	title_scraper_end_status_key = "Scraped the title of the abstract"
	status_logger(status_logger_name, title_scraper_end_status_key)
	return title

def abstract_id_scraper(abstract_id_log_name, page_soup, site_url_index, status_logger_name):
	'''This function helps in obtaining the PII number of the abstract.
	This number is then coupled with the dynamic URL and provides'''

	abstract_id_scraper_start_status_key="Scraping IDs"
	status_logger(status_logger_name, abstract_id_scraper_start_status_key)
	''''This statement collects all the input tags that have the abstract ids in them'''
	abstract_input_tags = page_soup.findAll('a', {'class':'title'})
	for abstract_input_tag in abstract_input_tags:
		abstract_input_tag_id=abstract_input_tag.get('href')
		abstract_id_database_writer(abstract_id_log_name, abstract_input_tag_id, site_url_index)

	abstract_id_scraper_stop_status_key="Scraped IDs"
	status_logger(status_logger_name, abstract_id_scraper_stop_status_key)

def word_sorter_list_generator(status_logger_name):
	word_sorter_list_generator_start_status_key = "Generating the permanent archival list"
	status_logger(status_logger_name, word_sorter_list_generator_start_status_key)
	'''This function generates the list that hold the Words and corresponding Years of the
	abstract data words before the actual recursion of scrapping data from the website begins.'''
	word_sorter_list = []

	word_sorter_list_generator_exit_status_key = "Generated the permanent archival list"
	status_logger(status_logger_name, word_sorter_list_generator_exit_status_key)
	return word_sorter_list

def delay_function(status_logger_name):
	'''Since the Springer servers are contstantly shutting down the remote connection, we introduce
	this function in the processor function in order to reduce the number of pings it delivers to the remote.'''
	delay_function_start_status_key = "Delaying remote server ping: 15 seconds"
	status_logger(status_logger_name, delay_function_start_status_key)

	delay_variable = np.random.randint(0, 10)
	'''Sleep parameter causes the code to be be delayed by 1 second'''
	time.sleep(delay_variable)

	delay_function_end_status_key = "Delayed remote server ping: 15 seconds"
	status_logger(status_logger_name, delay_function_end_status_key)

def processor(abstract_url, urls_to_scrape, abstract_id_log_name, abstracts_log_name, status_logger_name, trend_keywords, keywords_to_search):
	''''Multiple page-cycling function to scrape multiple result pages returned from Springer.
	print(len(urls_to_scrape))'''
	
	'''This list will hold all the words mentioned in all the abstracts. It will be later passed on to the
	visualizer code to generate the trends histogram.'''
	permanent_word_sorter_list = word_sorter_list_generator(status_logger_name)

	for site_url_index in range(0, len(urls_to_scrape)):

		if(site_url_index==0):
			results_determiner(urls_to_scrape[site_url_index], status_logger_name)
		'''Collects the web-page from the url for souping'''
		page_to_soup = url_reader(urls_to_scrape[site_url_index], status_logger_name)
		'''Souping the page for collection of data and tags'''
		page_soup = page_souper(page_to_soup, status_logger_name)
		'''Scrapping the page to extract all the abstract IDs'''
		abstract_id_scraper(abstract_id_log_name, page_soup, site_url_index, status_logger_name)
		'''Actually obtaining the abstracts after combining ID with the abstract_url'''
		abstract_crawler(abstract_url, abstract_id_log_name, abstracts_log_name, permanent_word_sorter_list, trend_keywords, site_url_index, status_logger_name)

	'''This line of code processes and generates a dictionary from the abstract data'''
	
	abstract_year_dictionary, starting_year, ending_year = abstract_year_list_post_processor(permanent_word_sorter_list, status_logger_name)

	return abstract_year_dictionary, starting_year, ending_year

def scraper_main(abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, trend_keywords, keywords_to_search, status_logger_name):
	''''This function contains all the functions and contains this entire script here, so that it can be imported later to the main function'''

	'''Provides the links for the URLs to be scraped by the scraper'''
	urls_to_scrape = url_generator(start_url, query_string, status_logger_name)
	'''Calling the processor() function here'''
	abstract_year_dictionary, starting_year, ending_year = processor(abstract_url, urls_to_scrape, abstract_id_log_name, abstracts_log_name, status_logger_name, trend_keywords, keywords_to_search)
	'''This function dumps the entire dictionary onto the disc for further analysis and inference.'''
	abstract_year_dictionary_dumper(abstract_year_dictionary, abstracts_log_name, status_logger_name)
	'''Returning the abstract word dictionary here'''
	return abstract_year_dictionary, starting_year, ending_year

# %% [markdown]
# Calling the ```scraper_main()``` function here.

# %%
scraper_main(abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, trend_keywords, keywords_to_search, status_logger_name)
# Out:
# [INFO]14:22:35 https://link.springer.com/search/page/0?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:37 https://link.springer.com/search/page/1?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:39 https://link.springer.com/search/page/2?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:41 https://link.springer.com/search/page/3?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:43 https://link.springer.com/search/page/4?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:44 https://link.springer.com/search/page/5?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:46 https://link.springer.com/search/page/6?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:48 https://link.springer.com/search/page/7?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:50 https://link.springer.com/search/page/8?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:52 https://link.springer.com/search/page/9?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:54 https://link.springer.com/search/page/10?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:55 https://link.springer.com/search/page/11?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:57 https://link.springer.com/search/page/12?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:22:59 https://link.springer.com/search/page/13?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:2 https://link.springer.com/search/page/14?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:4 https://link.springer.com/search/page/15?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:5 https://link.springer.com/search/page/16?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:7 https://link.springer.com/search/page/17?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:9 https://link.springer.com/search/page/18?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:10 https://link.springer.com/search/page/19?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:11 https://link.springer.com/search/page/20?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:13 https://link.springer.com/search/page/21?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:14 https://link.springer.com/search/page/22?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:15 https://link.springer.com/search/page/23?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:17 https://link.springer.com/search/page/24?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:18 https://link.springer.com/search/page/25?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:19 https://link.springer.com/search/page/26?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:21 https://link.springer.com/search/page/27?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:22 https://link.springer.com/search/page/28?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:24 https://link.springer.com/search/page/29?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:25 https://link.springer.com/search/page/30?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:26 https://link.springer.com/search/page/31?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:28 https://link.springer.com/search/page/32?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:29 https://link.springer.com/search/page/33?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:30 https://link.springer.com/search/page/34?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:32 https://link.springer.com/search/page/35?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:33 https://link.springer.com/search/page/36?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:35 https://link.springer.com/search/page/37?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:36 https://link.springer.com/search/page/38?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:38 https://link.springer.com/search/page/39?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:40 https://link.springer.com/search/page/40?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:42 https://link.springer.com/search/page/41?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:43 https://link.springer.com/search/page/42?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:45 https://link.springer.com/search/page/43?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:47 https://link.springer.com/search/page/44?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:48 https://link.springer.com/search/page/45?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:50 https://link.springer.com/search/page/46?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:51 https://link.springer.com/search/page/47?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:53 https://link.springer.com/search/page/48?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:55 https://link.springer.com/search/page/49?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:57 https://link.springer.com/search/page/50?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:23:59 https://link.springer.com/search/page/51?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:0 https://link.springer.com/search/page/52?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:2 https://link.springer.com/search/page/53?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:4 https://link.springer.com/search/page/54?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:6 https://link.springer.com/search/page/55?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:7 https://link.springer.com/search/page/56?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:9 https://link.springer.com/search/page/57?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:11 https://link.springer.com/search/page/58?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:12 https://link.springer.com/search/page/59?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:13 https://link.springer.com/search/page/60?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:14 https://link.springer.com/search/page/61?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:16 https://link.springer.com/search/page/62?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:17 https://link.springer.com/search/page/63?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:19 https://link.springer.com/search/page/64?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:20 https://link.springer.com/search/page/65?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:21 https://link.springer.com/search/page/66?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:23 https://link.springer.com/search/page/67?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:24 https://link.springer.com/search/page/68?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:26 https://link.springer.com/search/page/69?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:27 https://link.springer.com/search/page/70?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:29 https://link.springer.com/search/page/71?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:30 https://link.springer.com/search/page/72?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:32 https://link.springer.com/search/page/73?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:33 https://link.springer.com/search/page/74?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:34 https://link.springer.com/search/page/75?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:36 https://link.springer.com/search/page/76?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:37 https://link.springer.com/search/page/77?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:39 https://link.springer.com/search/page/78?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:41 https://link.springer.com/search/page/79?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:43 https://link.springer.com/search/page/80?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:44 https://link.springer.com/search/page/81?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:46 https://link.springer.com/search/page/82?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:48 https://link.springer.com/search/page/83?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:50 https://link.springer.com/search/page/84?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:51 https://link.springer.com/search/page/85?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:53 https://link.springer.com/search/page/86?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:54 https://link.springer.com/search/page/87?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:55 https://link.springer.com/search/page/88?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:57 https://link.springer.com/search/page/89?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:24:59 https://link.springer.com/search/page/90?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:0 https://link.springer.com/search/page/91?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:1 https://link.springer.com/search/page/92?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:2 https://link.springer.com/search/page/93?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:4 https://link.springer.com/search/page/94?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:5 https://link.springer.com/search/page/95?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:7 https://link.springer.com/search/page/96?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:8 https://link.springer.com/search/page/97?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:9 https://link.springer.com/search/page/98?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:11 https://link.springer.com/search/page/99?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:12 https://link.springer.com/search/page/100?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:14 https://link.springer.com/search/page/101?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:15 https://link.springer.com/search/page/102?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:16 https://link.springer.com/search/page/103?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:18 https://link.springer.com/search/page/104?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:19 https://link.springer.com/search/page/105?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:21 https://link.springer.com/search/page/106?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:22 https://link.springer.com/search/page/107?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:24 https://link.springer.com/search/page/108?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:26 https://link.springer.com/search/page/109?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:27 https://link.springer.com/search/page/110?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:29 https://link.springer.com/search/page/111?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:30 https://link.springer.com/search/page/112?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:32 https://link.springer.com/search/page/113?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:33 https://link.springer.com/search/page/114?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:35 https://link.springer.com/search/page/115?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:36 https://link.springer.com/search/page/116?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:37 https://link.springer.com/search/page/117?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:39 https://link.springer.com/search/page/118?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:40 https://link.springer.com/search/page/119?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:41 https://link.springer.com/search/page/120?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:43 https://link.springer.com/search/page/121?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:44 https://link.springer.com/search/page/122?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:45 https://link.springer.com/search/page/123?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:46 https://link.springer.com/search/page/124?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:48 https://link.springer.com/search/page/125?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:49 https://link.springer.com/search/page/126?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:50 https://link.springer.com/search/page/127?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:52 https://link.springer.com/search/page/128?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:53 https://link.springer.com/search/page/129?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:55 https://link.springer.com/search/page/130?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:57 https://link.springer.com/search/page/131?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:25:58 https://link.springer.com/search/page/132?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:0 https://link.springer.com/search/page/133?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:1 https://link.springer.com/search/page/134?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:3 https://link.springer.com/search/page/135?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:4 https://link.springer.com/search/page/136?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:6 https://link.springer.com/search/page/137?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:7 https://link.springer.com/search/page/138?facet-content-type="Article"&query=Endemic+Species+Atlantic+Forests has been obtained
# [INFO]14:26:7 Generating the permanent archival list
# [INFO]14:26:7 Generated the permanent archival list
# [INFO]14:26:10 Page status: 200
# [INFO]14:26:10 Souping page
# [INFO]14:26:11 Souped page
# [INFO]14:26:11 Scraping IDs
# [INFO]14:26:11 Scraped IDs
# [INFO]14:26:11 Extracting Abstract IDs from disc
# [INFO]14:26:11 Extracted Abstract IDs from disc
# [INFO]14:26:11 Abstract Number: 1
# [INFO]14:26:11 Abstract ID: /article/10.1007/s12228-018-9526-4
# [INFO]14:26:11 Page status: 200
# [INFO]14:26:11 Souping page
# [INFO]14:26:12 Souped page
# [INFO]14:26:12 Scraping the title of the abstract
# [INFO]14:26:12 Scraped the title of the abstract
# [INFO]14:26:12 Scraping date of the abstract titled: 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil'
# [INFO]14:26:12 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' was published on 2018-09
# [INFO]14:26:12 Scraping the author name
# [INFO]14:26:12 Scraped the author name
# [INFO]14:26:12 Adding: 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' to the archival list
# [INFO]14:26:12 Added: 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' to the archival list
# [INFO]14:26:12 Writing 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' by 'Rafael\xc2\xa0Felipe\xc2\xa0de\xc2\xa0Almeida' to disc
# [INFO]14:26:12 Written 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' to disc
# [INFO]14:26:12 Writing 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' by 'Rafael\xc2\xa0Felipe\xc2\xa0de\xc2\xa0Almeida' to analytical abstracts file
# [INFO]14:26:12 Written 'Rediscovery of Banisteriopsis magdalenensis (Malpighiaceae): Notes on morphology, distribution, and ecology of an endemic and threatened species from the Atlantic Forest of Brazil' to disc
# [INFO]14:26:12 Delaying remote server ping: 15 seconds
# [INFO]14:26:20 Delayed remote server ping: 15 seconds
# [INFO]14:26:20 Abstract Number: 2
# [INFO]14:26:20 Abstract ID: /article/10.1023/B%3ABIOC.0000040005.89375.c0
# [INFO]14:26:21 Page status: 200
# [INFO]14:26:21 Souping page
# [INFO]14:26:21 Souped page
# [INFO]14:26:21 Scraping the title of the abstract
# [INFO]14:26:21 Scraped the title of the abstract
# [INFO]14:26:21 Scraping date of the abstract titled: 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest'
# [INFO]14:26:21 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' was published on 2004-10
# [INFO]14:26:21 Scraping the author name
# [INFO]14:26:21 Scraped the author name
# [INFO]14:26:21 Adding: 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' to the archival list
# [INFO]14:26:21 Added: 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' to the archival list
# [INFO]14:26:21 Writing 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' by 'Daniel\xc2\xa0Brito' to disc
# [INFO]14:26:21 Written 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' to disc
# [INFO]14:26:21 Writing 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' by 'Daniel\xc2\xa0Brito' to analytical abstracts file
# [INFO]14:26:21 Written 'Lack of adequate taxonomic knowledge may hinder endemic mammal conservation in the Brazilian Atlantic Forest' to disc
# [INFO]14:26:21 Delaying remote server ping: 15 seconds
# [INFO]14:26:29 Delayed remote server ping: 15 seconds
# [INFO]14:26:29 Abstract Number: 3
# [INFO]14:26:29 Abstract ID: /article/10.1007/s10336-006-0093-1
# [INFO]14:26:31 Page status: 200
# [INFO]14:26:31 Souping page
# [INFO]14:26:31 Souped page
# [INFO]14:26:31 Scraping the title of the abstract
# [INFO]14:26:31 Scraped the title of the abstract
# [INFO]14:26:31 Scraping date of the abstract titled: 'Abstract'
# [INFO]14:26:31 'Abstract' was published on 2006-08
# [INFO]14:26:31 Scraping the author name
# [INFO]14:26:31 Writing 'Abstract' by Author not available to disc
# [INFO]14:26:31 Written 'Abstract' to disc
# [INFO]14:26:31 Writing 'Abstract' by Author not available to analytical abstracts file
# [INFO]14:26:31 Written 'Abstract' to disc
# [INFO]14:26:31 Delaying remote server ping: 15 seconds
# [INFO]14:26:39 Delayed remote server ping: 15 seconds
# [INFO]14:26:39 Abstract Number: 4
# [INFO]14:26:39 Abstract ID: /article/10.1007/s13592-014-0329-7
# [INFO]14:26:40 Page status: 200
# [INFO]14:26:40 Souping page
# [INFO]14:26:41 Souped page
# [INFO]14:26:41 Scraping the title of the abstract
# [INFO]14:26:41 Scraped the title of the abstract
# [INFO]14:26:41 Scraping date of the abstract titled: 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest'
# [INFO]14:26:41 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' was published on 2015-05
# [INFO]14:26:41 Scraping the author name
# [INFO]14:26:41 Scraped the author name
# [INFO]14:26:41 Adding: 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' to the archival list
# [INFO]14:26:41 Added: 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' to the archival list
# [INFO]14:26:41 Writing 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' by 'Rafael\xc2\xa0E.\xc2\xa0S.\xc2\xa0Penha' to disc
# [INFO]14:26:41 Written 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' to disc
# [INFO]14:26:41 Writing 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' by 'Rafael\xc2\xa0E.\xc2\xa0S.\xc2\xa0Penha' to analytical abstracts file
# [INFO]14:26:41 Written 'Mitochondrial DNA of Euglossa iopoecila (Apidae, Euglossini) reveals two distinct lineages for this orchid bee species endemic to the Atlantic Forest' to disc
# [INFO]14:26:41 Delaying remote server ping: 15 seconds
# [INFO]14:26:47 Delayed remote server ping: 15 seconds
# [INFO]14:26:47 Abstract Number: 5
# [INFO]14:26:47 Abstract ID: /article/10.1007/s10592-014-0607-y
# [INFO]14:26:48 Page status: 200
# [INFO]14:26:48 Souping page
# [INFO]14:26:50 Souped page
# [INFO]14:26:50 Scraping the title of the abstract
# [INFO]14:26:50 Scraped the title of the abstract
# [INFO]14:26:50 Scraping date of the abstract titled: 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil'
# [INFO]14:26:50 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' was published on 2014-10
# [INFO]14:26:50 Scraping the author name
# [INFO]14:26:50 Scraped the author name
# [INFO]14:26:50 Adding: 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' to the archival list
# [INFO]14:26:50 Added: 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' to the archival list
# [INFO]14:26:50 Writing 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' by 'Denise\xc2\xa0M.\xc2\xa0Nogueira' to disc
# [INFO]14:26:50 Written 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' to disc
# [INFO]14:26:50 Writing 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' by 'Denise\xc2\xa0M.\xc2\xa0Nogueira' to analytical abstracts file
# [INFO]14:26:50 Written 'Genetic differentiation over a short water barrier in the Brazilian tanager, Ramphocelus bresilius (Passeriformes: Thraupidae) an endemic species of the Atlantic forest, Brazil' to disc
# [INFO]14:26:50 Delaying remote server ping: 15 seconds
# [INFO]14:26:53 Delayed remote server ping: 15 seconds
# [INFO]14:26:53 Abstract Number: 6
# [INFO]14:26:53 Abstract ID: /article/10.1007/s10709-005-1448-x
# [INFO]14:26:54 Page status: 200
# [INFO]14:26:54 Souping page
# [INFO]14:26:55 Souped page
# [INFO]14:26:55 Scraping the title of the abstract
# [INFO]14:26:55 Scraped the title of the abstract
# [INFO]14:26:55 Scraping date of the abstract titled: 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)'
# [INFO]14:26:55 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' was published on 2006-01
# [INFO]14:26:55 Scraping the author name
# [INFO]14:26:55 Scraped the author name
# [INFO]14:26:55 Adding: 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' to the archival list
# [INFO]14:26:55 Added: 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' to the archival list
# [INFO]14:26:55 Writing 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' by 'Nadia\xc2\xa0de\xc2\xa0Moraes-Barros' to disc
# [INFO]14:26:55 Written 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' to disc
# [INFO]14:26:55 Writing 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' by 'Nadia\xc2\xa0de\xc2\xa0Moraes-Barros' to analytical abstracts file
# [INFO]14:26:55 Written 'Comparative Phylogeography of the Atlantic Forest Endemic Sloth (Bradypus torquatus) and the Widespread Three-toed Sloth (Bradypus variegatus) (Bradypodidae, Xenarthra)' to disc
# [INFO]14:26:55 Delaying remote server ping: 15 seconds
# [INFO]14:27:2 Delayed remote server ping: 15 seconds
# [INFO]14:27:2 Abstract Number: 7
# [INFO]14:27:2 Abstract ID: /article/10.1007/s11284-012-0977-x
# [INFO]14:27:3 Page status: 200
# [INFO]14:27:3 Souping page
# [INFO]14:27:4 Souped page
# [INFO]14:27:4 Scraping the title of the abstract
# [INFO]14:27:4 Scraped the title of the abstract
# [INFO]14:27:4 Scraping date of the abstract titled: 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal'
# [INFO]14:27:4 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' was published on 2012-11
# [INFO]14:27:4 Scraping the author name
# [INFO]14:27:4 Scraped the author name
# [INFO]14:27:4 Adding: 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' to the archival list
# [INFO]14:27:4 Added: 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' to the archival list
# [INFO]14:27:4 Writing 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' by 'Maja\xc2\xa0Kajin' to disc
# [INFO]14:27:4 Written 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' to disc
# [INFO]14:27:4 Writing 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' by 'Maja\xc2\xa0Kajin' to analytical abstracts file
# [INFO]14:27:4 Written 'Microhabitat selection when detection is imperfect: the case of an endemic Atlantic forest mammal' to disc
# [INFO]14:27:4 Delaying remote server ping: 15 seconds
# [INFO]14:27:6 Delayed remote server ping: 15 seconds
# [INFO]14:27:6 Abstract Number: 8
# [INFO]14:27:6 Abstract ID: /article/10.1007/s40415-017-0384-1
# [INFO]14:27:6 Page status: 200
# [INFO]14:27:6 Souping page
# [INFO]14:27:7 Souped page
# [INFO]14:27:7 Scraping the title of the abstract
# [INFO]14:27:7 Scraped the title of the abstract
# [INFO]14:27:7 Scraping date of the abstract titled: 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest'
# [INFO]14:27:7 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' was published on 2017-09
# [INFO]14:27:7 Scraping the author name
# [INFO]14:27:7 Scraped the author name
# [INFO]14:27:7 Adding: 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' to the archival list
# [INFO]14:27:7 Added: 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' to the archival list
# [INFO]14:27:7 Writing 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' by 'Vin\xc3\xadcius\xc2\xa0Trettel\xc2\xa0Rodrigues' to disc
# [INFO]14:27:7 Written 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' to disc
# [INFO]14:27:7 Writing 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' by 'Vin\xc3\xadcius\xc2\xa0Trettel\xc2\xa0Rodrigues' to analytical abstracts file
# [INFO]14:27:7 Written 'Phylogeny of Acianthera sect. Pleurobotryae (Orchidaceae: Pleurothallidinae), an endemic group of the Atlantic Forest' to disc
# [INFO]14:27:7 Delaying remote server ping: 15 seconds
# [INFO]14:27:15 Delayed remote server ping: 15 seconds
# [INFO]14:27:15 Abstract Number: 9
# [INFO]14:27:15 Abstract ID: /article/10.1007/s10681-014-1273-3
# [INFO]14:27:16 Page status: 200
# [INFO]14:27:16 Souping page
# [INFO]14:27:18 Souped page
# [INFO]14:27:18 Scraping the title of the abstract
# [INFO]14:27:18 Scraped the title of the abstract
# [INFO]14:27:18 Scraping date of the abstract titled: 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest'
# [INFO]14:27:18 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' was published on 2015-07
# [INFO]14:27:18 Scraping the author name
# [INFO]14:27:18 Scraped the author name
# [INFO]14:27:18 Adding: 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' to the archival list
# [INFO]14:27:18 Added: 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' to the archival list
# [INFO]14:27:18 Writing 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' by 'Everton\xc2\xa0Hilo\xc2\xa0de\xc2\xa0Souza' to disc
# [INFO]14:27:18 Written 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' to disc
# [INFO]14:27:18 Writing 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' by 'Everton\xc2\xa0Hilo\xc2\xa0de\xc2\xa0Souza' to analytical abstracts file
# [INFO]14:27:18 Written 'Viability, storage and ultrastructure analysis of Aechmea bicolor (Bromeliaceae) pollen grains, an endemic species to the Atlantic forest' to disc
# [INFO]14:27:18 Delaying remote server ping: 15 seconds
# [INFO]14:27:20 Delayed remote server ping: 15 seconds
# [INFO]14:27:20 Abstract Number: 10
# [INFO]14:27:20 Abstract ID: /article/10.1023/B%3ABIOC.0000048450.85086.00
# [INFO]14:27:20 Page status: 200
# [INFO]14:27:20 Souping page
# [INFO]14:27:21 Souped page
# [INFO]14:27:21 Scraping the title of the abstract
# [INFO]14:27:21 Scraped the title of the abstract
# [INFO]14:27:21 Scraping date of the abstract titled: 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil'
# [INFO]14:27:21 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' was published on 2004-12
# [INFO]14:27:21 Scraping the author name
# [INFO]14:27:21 Scraped the author name
# [INFO]14:27:21 Adding: 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' to the archival list
# [INFO]14:27:21 Added: 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' to the archival list
# [INFO]14:27:21 Writing 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' by 'Daniel\xc2\xa0Brito' to disc
# [INFO]14:27:21 Written 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' to disc
# [INFO]14:27:21 Writing 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' by 'Daniel\xc2\xa0Brito' to analytical abstracts file
# [INFO]14:27:21 Written 'Effectiveness of a reserve network for the conservation of the endemic marsupial Micoureus travassosi in Atlantic Forest remnants in southeastern Brazil' to disc
# [INFO]14:27:21 Delaying remote server ping: 15 seconds
# [INFO]14:27:21 Delayed remote server ping: 15 seconds
# [INFO]14:27:21 Abstract Number: 11
# [INFO]14:27:21 Abstract ID: /article/10.1007/s10336-012-0901-8
# [INFO]14:27:22 Page status: 200
# [INFO]14:27:22 Souping page
# [INFO]14:27:23 Souped page
# [INFO]14:27:23 Scraping the title of the abstract
# [INFO]14:27:23 Scraped the title of the abstract
# [INFO]14:27:23 Scraping date of the abstract titled: 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)'
# [INFO]14:27:23 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' was published on 2013-04
# [INFO]14:27:23 Scraping the author name
# [INFO]14:27:23 Scraped the author name
# [INFO]14:27:23 Adding: 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' to the archival list
# [INFO]14:27:23 Added: 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' to the archival list
# [INFO]14:27:23 Writing 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' by 'G.\xc2\xa0S.\xc2\xa0Cabanne' to disc
# [INFO]14:27:23 Written 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' to disc
# [INFO]14:27:23 Writing 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' by 'G.\xc2\xa0S.\xc2\xa0Cabanne' to analytical abstracts file
# [INFO]14:27:23 Written 'Matrilineal evidence for demographic expansion, low diversity and lack of phylogeographic structure in the Atlantic forest endemic Greenish Schiffornis Schiffornis virescens (Aves: Tityridae)' to disc
# [INFO]14:27:23 Delaying remote server ping: 15 seconds
# [INFO]14:27:28 Delayed remote server ping: 15 seconds
# [INFO]14:27:28 Abstract Number: 12
# [INFO]14:27:28 Abstract ID: /article/10.1007/s10531-015-0939-z
# [INFO]14:27:29 Page status: 200
# [INFO]14:27:29 Souping page
# [INFO]14:27:30 Souped page
# [INFO]14:27:30 Scraping the title of the abstract
# [INFO]14:27:30 Scraped the title of the abstract
# [INFO]14:27:30 Scraping date of the abstract titled: 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest'
# [INFO]14:27:30 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' was published on 2015-09
# [INFO]14:27:30 Scraping the author name
# [INFO]14:27:30 Scraped the author name
# [INFO]14:27:30 Adding: 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' to the archival list
# [INFO]14:27:30 Added: 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' to the archival list
# [INFO]14:27:30 Writing 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' by 'Vanessa\xc2\xa0L.\xc2\xa0Rezende' to disc
# [INFO]14:27:30 Written 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' to disc
# [INFO]14:27:30 Writing 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' by 'Vanessa\xc2\xa0L.\xc2\xa0Rezende' to analytical abstracts file
# [INFO]14:27:30 Written 'Tree species composition and richness along altitudinal gradients as a tool for conservation decisions: the case of Atlantic semideciduous forest' to disc
# [INFO]14:27:30 Delaying remote server ping: 15 seconds
# [INFO]14:27:34 Delayed remote server ping: 15 seconds
# [INFO]14:27:34 Abstract Number: 13
# [INFO]14:27:34 Abstract ID: /article/10.1186/1810-522X-52-55
# [INFO]14:27:35 Page status: 200
# [INFO]14:27:35 Souping page
# [INFO]14:27:37 Souped page
# [INFO]14:27:37 Scraping the title of the abstract
# [INFO]14:27:37 Scraped the title of the abstract
# [INFO]14:27:37 Scraping date of the abstract titled: 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)'
# [INFO]14:27:37 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' was published on 2013-12
# [INFO]14:27:37 Scraping the author name
# [INFO]14:27:37 Scraped the author name
# [INFO]14:27:37 Adding: 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' to the archival list
# [INFO]14:27:37 Added: 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' to the archival list
# [INFO]14:27:37 Writing 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' by 'Karen\xc2\xa0Ventura' to disc
# [INFO]14:27:37 Written 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' to disc
# [INFO]14:27:37 Writing 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' by 'Karen\xc2\xa0Ventura' to analytical abstracts file
# [INFO]14:27:37 Written 'The phylogenetic position of the enigmatic Atlantic forest-endemic spiny mouse Abrawayaomys (Rodentia: Sigmodontinae)' to disc
# [INFO]14:27:37 Delaying remote server ping: 15 seconds
# [INFO]14:27:43 Delayed remote server ping: 15 seconds
# [INFO]14:27:43 Abstract Number: 14
# [INFO]14:27:43 Abstract ID: /article/10.1007/s10531-004-5019-8
# [INFO]14:27:43 Page status: 200
# [INFO]14:27:43 Souping page
# [INFO]14:27:44 Souped page
# [INFO]14:27:44 Scraping the title of the abstract
# [INFO]14:27:44 Scraped the title of the abstract
# [INFO]14:27:44 Scraping date of the abstract titled: 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest'
# [INFO]14:27:44 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' was published on 2006-05
# [INFO]14:27:44 Scraping the author name
# [INFO]14:27:44 Scraped the author name
# [INFO]14:27:44 Adding: 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' to the archival list
# [INFO]14:27:44 Added: 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' to the archival list
# [INFO]14:27:44 Writing 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' by 'Daniel\xc2\xa0Brito' to disc
# [INFO]14:27:44 Written 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' to disc
# [INFO]14:27:44 Writing 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' by 'Daniel\xc2\xa0Brito' to analytical abstracts file
# [INFO]14:27:44 Written 'Evaluation of Minimum Viable Population Size and Conservation Status of the Long-furred Woolly Mouse Opossum Micoureus paraguayanus: An Endemic Marsupial of the Atlantic Forest' to disc
# [INFO]14:27:44 Delaying remote server ping: 15 seconds
# [INFO]14:27:50 Delayed remote server ping: 15 seconds
# [INFO]14:27:50 Abstract Number: 15
# [INFO]14:27:50 Abstract ID: /article/10.1007/s10336-014-1106-0
# [INFO]14:27:51 Page status: 200
# [INFO]14:27:51 Souping page
# [INFO]14:27:52 Souped page
# [INFO]14:27:52 Scraping the title of the abstract
# ...
# [INFO]14:30:1 Written 'Population genetic structure of the Atlantic Forest endemic Conopophaga lineata (Passeriformes: Conopophagidae) reveals a contact zone in the Atlantic Forest' to disc
# [INFO]14:30:1 Delaying remote server ping: 15 seconds
# [INFO]14:30:4 Delayed remote server ping: 15 seconds
# [INFO]14:30:4 Abstract Number: 36
# [INFO]14:30:4 Abstract ID: /article/10.1186/1471-2148-13-178
# [INFO]14:30:5 Page status: 200
# [INFO]14:30:5 Souping page
# [INFO]14:30:6 Souped page
# [INFO]14:30:6 Scraping the title of the abstract
# [INFO]14:30:6 Scraped the title of the abstract
# [INFO]14:30:6 Scraping date of the abstract titled: 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia'
# [INFO]14:30:6 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' was published on 2013-12
# [INFO]14:30:6 Scraping the author name
# [INFO]14:30:6 Scraped the author name
# [INFO]14:30:6 Adding: 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' to the archival list
# [INFO]14:30:6 Added: 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' to the archival list
# [INFO]14:30:6 Writing 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' by 'Geraldo\xc2\xa0M\xc3\xa4der' to disc
# [INFO]14:30:6 Written 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' to disc
# [INFO]14:30:6 Writing 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' by 'Geraldo\xc2\xa0M\xc3\xa4der' to analytical abstracts file
# [INFO]14:30:6 Written 'Geological and climatic changes in quaternary shaped the evolutionary history of Calibrachoa heterophylla, an endemic South-Atlantic species of petunia' to disc
# [INFO]14:30:6 Delaying remote server ping: 15 seconds
# [INFO]14:30:11 Delayed remote server ping: 15 seconds
# [INFO]14:30:11 Abstract Number: 37
# [INFO]14:30:11 Abstract ID: /article/10.1007/s12686-014-0288-3
# [INFO]14:30:12 Page status: 200
# [INFO]14:30:12 Souping page
# [INFO]14:30:13 Souped page
# [INFO]14:30:13 Scraping the title of the abstract
# [INFO]14:30:13 Scraped the title of the abstract
# [INFO]14:30:13 Scraping date of the abstract titled: 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest'
# [INFO]14:30:13 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' was published on 2015-03
# [INFO]14:30:13 Scraping the author name
# [INFO]14:30:13 Scraped the author name
# [INFO]14:30:13 Adding: 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' to the archival list
# [INFO]14:30:13 Added: 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' to the archival list
# [INFO]14:30:13 Writing 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' by 'Daniela\xc2\xa0B.\xc2\xa0Borges' to disc
# [INFO]14:30:13 Written 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' to disc
# [INFO]14:30:13 Writing 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' by 'Daniela\xc2\xa0B.\xc2\xa0Borges' to analytical abstracts file
# [INFO]14:30:13 Written 'Development of microsatellite primers for Melanoxylon brauna (Fabaceae): an endangered and endemic tree from the Brazilian Atlantic Forest' to disc
# [INFO]14:30:13 Delaying remote server ping: 15 seconds
# [INFO]14:30:22 Delayed remote server ping: 15 seconds
# [INFO]14:30:22 Abstract Number: 38
# [INFO]14:30:22 Abstract ID: /article/10.1023/A%3A1018368809116
# [INFO]14:30:24 Page status: 200
# [INFO]14:30:24 Souping page
# [INFO]14:30:24 Souped page
# [INFO]14:30:24 Scraping the title of the abstract
# [INFO]14:30:24 Scraped the title of the abstract
# [INFO]14:30:24 Scraping date of the abstract titled: 'Endemic bird species and conservation in the Cerrado Region, South America'
# [INFO]14:30:24 'Endemic bird species and conservation in the Cerrado Region, South America' was published on 1997-03
# [INFO]14:30:24 Scraping the author name
# [INFO]14:30:24 Scraped the author name
# [INFO]14:30:24 Adding: 'Endemic bird species and conservation in the Cerrado Region, South America' to the archival list
# [INFO]14:30:24 Added: 'Endemic bird species and conservation in the Cerrado Region, South America' to the archival list
# [INFO]14:30:24 Writing 'Endemic bird species and conservation in the Cerrado Region, South America' by 'Jose\xc2\xb4\xc2\xa0Maria\xc2\xa0Cardoso\xc2\xa0Da\xc2\xa0Silva' to disc
# [INFO]14:30:24 Written 'Endemic bird species and conservation in the Cerrado Region, South America' to disc
# [INFO]14:30:24 Writing 'Endemic bird species and conservation in the Cerrado Region, South America' by 'Jose\xc2\xb4\xc2\xa0Maria\xc2\xa0Cardoso\xc2\xa0Da\xc2\xa0Silva' to analytical abstracts file
# [INFO]14:30:24 Written 'Endemic bird species and conservation in the Cerrado Region, South America' to disc
# [INFO]14:30:24 Delaying remote server ping: 15 seconds
# [INFO]14:30:24 Delayed remote server ping: 15 seconds
# [INFO]14:30:24 Abstract Number: 39
# [INFO]14:30:24 Abstract ID: /article/10.1007/s10531-005-2089-1
# [INFO]14:30:25 Page status: 200
# [INFO]14:30:25 Souping page
# [INFO]14:30:26 Souped page
# [INFO]14:30:26 Scraping the title of the abstract
# [INFO]14:30:26 Scraped the title of the abstract
# [INFO]14:30:26 Scraping date of the abstract titled: 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil'
# [INFO]14:30:26 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' was published on 2006-02
# [INFO]14:30:26 Scraping the author name
# [INFO]14:30:26 Scraped the author name
# [INFO]14:30:26 Adding: 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' to the archival list
# [INFO]14:30:26 Added: 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' to the archival list
# [INFO]14:30:26 Writing 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' by 'Deborah\xc2\xa0Faria' to disc
# [INFO]14:30:26 Written 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' to disc
# [INFO]14:30:26 Writing 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' by 'Deborah\xc2\xa0Faria' to analytical abstracts file
# [INFO]14:30:26 Written 'Bat and Bird Assemblages from Forests and Shade Cacao Plantations in Two Contrasting Landscapes in the Atlantic Forest of Southern Bahia, Brazil' to disc
# [INFO]14:30:26 Delaying remote server ping: 15 seconds
# [INFO]14:30:34 Delayed remote server ping: 15 seconds
# [INFO]14:30:34 Abstract Number: 40
# [INFO]14:30:34 Abstract ID: /article/10.1007/s13127-015-0228-4
# [INFO]14:30:35 Page status: 200
# [INFO]14:30:35 Souping page
# [INFO]14:30:36 Souped page
# [INFO]14:30:36 Scraping the title of the abstract
# [INFO]14:30:36 Scraped the title of the abstract
# [INFO]14:30:36 Scraping date of the abstract titled: 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest'
# [INFO]14:30:36 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' was published on 2015-12
# [INFO]14:30:36 Scraping the author name
# [INFO]14:30:36 Scraped the author name
# [INFO]14:30:36 Adding: 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' to the archival list
# [INFO]14:30:36 Added: 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' to the archival list
# [INFO]14:30:36 Writing 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' by 'Tuliana\xc2\xa0O.\xc2\xa0Brunes' to disc
# [INFO]14:30:36 Written 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' to disc
# [INFO]14:30:36 Writing 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' by 'Tuliana\xc2\xa0O.\xc2\xa0Brunes' to analytical abstracts file
# [INFO]14:30:36 Written 'Ancient divergence and recent population expansion in a leaf frog endemic to the southern Brazilian Atlantic forest' to disc
# [INFO]14:30:36 Delaying remote server ping: 15 seconds
# [INFO]14:30:44 Delayed remote server ping: 15 seconds
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1253             try:
# -> 1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
#
# /usr/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /usr/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /usr/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /usr/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /usr/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /usr/lib/python3.5/http/client.py in connect(self)
#    1251
# -> 1252             super().connect()
#    1253
#
# /usr/lib/python3.5/http/client.py in connect(self)
#     848         self.sock = self._create_connection(
# --> 849             (self.host,self.port), self.timeout, self.source_address)
#     850         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /usr/lib/python3.5/socket.py in create_connection(address, timeout, source_address)
#     692     err = None
# --> 693     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     694         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-7-6eceec98769e> in <module>
# ----> 1 scraper_main(abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, trend_keywords, keywords_to_search, status_logger_name)
#
# <ipython-input-6-6c77ee1a8a79> in scraper_main(abstract_id_log_name, abstracts_log_name, start_url, abstract_url, query_string, trend_keywords, keywords_to_search, status_logger_name)
#     331         urls_to_scrape = url_generator(start_url, query_string, status_logger_name)
#     332         '''Calling the processor() function here'''
# --> 333         abstract_year_dictionary, starting_year, ending_year = processor(abstract_url, urls_to_scrape, abstract_id_log_name, abstracts_log_name, status_logger_name, trend_keywords, keywords_to_search)
#     334         '''This function dumps the entire dictionary onto the disc for further analysis and inference.'''
#     335         abstract_year_dictionary_dumper(abstract_year_dictionary, abstracts_log_name, status_logger_name)
#
# <ipython-input-6-6c77ee1a8a79> in processor(abstract_url, urls_to_scrape, abstract_id_log_name, abstracts_log_name, status_logger_name, trend_keywords, keywords_to_search)
#     311                         results_determiner(urls_to_scrape[site_url_index], status_logger_name)
#     312                 '''Collects the web-page from the url for souping'''
# --> 313                 page_to_soup = url_reader(urls_to_scrape[site_url_index], status_logger_name)
#     314                 '''Souping the page for collection of data and tags'''
#     315                 page_soup = page_souper(page_to_soup, status_logger_name)
#
# <ipython-input-6-6c77ee1a8a79> in url_reader(url, status_logger_name)
#       5 	moves on to the next PII number'''
#       6         try:
# ----> 7                 page=urlopen(url)
#       8                 page_status(page, status_logger_name)
#       9                 return page
#
# /usr/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /usr/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# /usr/lib/python3.5/urllib/request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# /usr/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /usr/lib/python3.5/urllib/request.py in https_open(self, req)
#    1295         def https_open(self, req):
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#    1299         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1254                 h.request(req.get_method(), req.selector, req.data, headers)
#    1255             except OSError as err: # timeout error
# -> 1256                 raise URLError(err)
#    1257             r = h.getresponse()
#    1258         except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>
