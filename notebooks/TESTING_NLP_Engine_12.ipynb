# %% [markdown]
# ### Natural Language Processing Script

# %% [markdown]
# This script can be used as a standalone program to process and prepare topic modelling of the ```Scraper.py``` datasets generated.

# %% [markdown]
# ### 1.0 <u>Code:</u>

# %% [markdown]
# Here, we import the libraries required to run the script.

# %%
'''Natural Language toolkit. Here we download the commonly used English stopwords'''
import nltk; nltk.download('stopwords')
'''Standard set of functions for reading and appending files'''
import re
'''Pandas and numpy is a dependency used by other portions of the code.'''
import numpy as np
import pandas as pd
'''Think this stands for pretty print. Prints out stuff to the terminal in a prettier way'''
from pprint import pprint

'''Contains the language model that has to be developed.'''
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
'''Industrial level toolkit for NLP'''
import spacy

'''Importing OS here to build the directories to hold the status logger logs'''
import os

import pyLDAvis
import pyLDAvis.gensim

'''Importing datetime here to log the time when specfic functions are triggered'''
from datetime import datetime

'''Make pretty visualizations'''
import matplotlib.pyplot as plt

'''Library to log any errors. Came across this in the tutorial.'''
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'com', 'https', 'url', 'link', 'xe', 'abstract', 'author', 'chapter', 'springer', 'title', "the", "of", "and", "in", "to", "a", "is", "for", "from", "with", "that","by", "are", "on", "was", "as", "were", "url:", "abstract:", "abstract",  "author:", "title:", "at", "be", "an", "during", "have", "this", "which", "study", "been", "species", "not", "has", "between", "using", "its", "also", "these", "this", "used", "over", "can", "within", "into", "all","due", "use", "about", "a", 'it', 'their', "where", "we", "most", "may", "through", "though", "like", "or", "further", "e.g.", "along", "any", "those", "had", "toward", "due", "both", "some", "use", "even", "more", "but", "while", "pass", "well", "will", "when", "only", "after", "author", "title", "there", "our", "did", "much", "as", "if", "become", "still", "various", "very", "out", "they", "via", "available", "such", "than", "different", "many", "areas", "no", "one", "two", "small", "first", "other", "such", "-", "could", "studies", "high","provide", "among", "highly", "no", "case", "across", "given", "need", "would", "under", "found", "low", "values", "xe2\\x80\\x89"])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sarthak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Defining the abstracts log name that will be processed by the rest of the script. The status logger function of the main script has been imported here, and the name of the ```.txt``` file used to log the information has to be added here.

# %%
abstracts_log_name = "/home/sarthak/projects/Bias/BackUp_Journal_LOGS/Test_Bed_Master_Copy/CompletelyCleanCorpus_12_Topics"
session_folder_name = abstracts_log_name.split('/')[7]
os.makedirs(session_folder_name)
status_logger_name = session_folder_name+"/"+"Status_Logger"+"_"+abstracts_log_name.split('/')[7]

# %% [markdown]
# This function is responsible for generating a ```.txt``` file for analysis once the code has run. This code has been copied directly from the ```common_functions.py``` script of the main code.

# %%
def status_logger(status_logger_name, status_key):
	'''Status logger to print and log details throught the running the program.
	Declaring current_hour, current_minute & current_second.'''
	current_hour = str(datetime.now().time().hour)
	current_minute = str(datetime.now().time().minute)
	current_second = str(datetime.now().time().second)
	'''Logging the complete_status_key and printing the complete_status_key'''
	complete_status_key = "[INFO]"+current_hour+":"+current_minute+":"+current_second+" "+status_key
	print(complete_status_key)
	status_log = open(status_logger_name+'.txt', 'a')
	status_log.write(complete_status_key+"\n")
	status_log.close()

# %% [markdown]
# Here, we read the ```.txt``` file generated from the journal scrapping, that has to be profiled using topic models.

# %%
def data_reader(abstracts_log_name, status_logger_name):
	data_reader_start_status_key = abstracts_log_name+".txt is being ported to dataframe"
	status_logger(status_logger_name, data_reader_start_status_key)
	textual_dataframe = pd.read_csv(abstracts_log_name+'.txt', delimiter="\t")
	data_reader_end_status_key = abstracts_log_name+".txt has been ported to dataframe"	
	status_logger(status_logger_name, data_reader_end_status_key)
	return textual_dataframe

# %% [markdown]
# Taking the abstracts and preparing a list of abstracts.

# %%
def textual_data_trimmer(textual_dataframe, status_logger_name):
	textual_data_trimmer_start_status_key = "Trimming data and preparing list of words"
	status_logger(status_logger_name, textual_data_trimmer_start_status_key)

	'''This function converts the textual data into a list and removes special characters, virtue of email correspondence'''
	textual_data = textual_dataframe.values.tolist()
	print(textual_data)

	textual_data_trimmer_end_status_key = "Trimmed data and prepared list of words"
	status_logger(status_logger_name, textual_data_trimmer_end_status_key)
	return textual_data

# %% [markdown]
# Tokenizing the words here and also removing punctuations from the corpus.

# %%
def sent_to_words(textual_data, status_logger_name):
	sent_to_words_start_status_key = "Tokenizing words"
	status_logger(status_logger_name, sent_to_words_start_status_key)
	'''This function tokenizes each sentence into individual words; also called tokens'''
	for sentence in textual_data:
		yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
	textual_data = list(sent_to_words(textual_data))
	sent_to_words_end_status_key = "Tokenized words"
	status_logger(status_logger_name, sent_to_words_end_status_key)	
	return textual_data

# %% [markdown]
# Generating ***```bigrams```*** from the ```textual_data``` that we have prepared from the abstracts. **Bigrams** are words that occur together, multiple times in a given body of text. For example, *torrential* and *rain* occur together more often with each other, as opposed to other adjective-noun pairs. Hence the two would form a bigram here.

# %%
def bigram_generator(textual_data, status_logger_name):
	bigram_generator_start_status_key = "Generating word bigrams"
	status_logger(status_logger_name, bigram_generator_start_status_key)	
	'''Takes the textual data and prepares the bigram, two collectively high frequency words'''
	bigram = gensim.models.Phrases(textual_data, min_count=5, threshold=100)
	bigram_mod = gensim.models.phrases.Phraser(bigram)
	bigram_generator_end_status_key = "Generated word bigrams"
	status_logger(status_logger_name, bigram_generator_end_status_key)	
	return bigram_mod

# %% [markdown]
# Here, we use the ```bigram_mod``` model to generate bigrams from our ```corpus```.

# %%
def make_bigrams(textual_data, status_logger_name):
	'''Generates multiple bigrams of word pairs in phrases that commonly occuring with each other over the corpus'''
	make_bigrams_start_status_key = "Generating bigrams"
	status_logger(status_logger_name, make_bigrams_start_status_key)

	bigram_mod = bigram_generator(textual_data, status_logger_name)
	return [bigram_mod[doc] for doc in textual_data]

	make_bigrams_end_status_key = "Generated bigrams"

# %% [markdown]
# We remove the stopwords, as specified in a list at the start of the program. There's a marked improvement in the topics and keywords produced after expanding the cache of the words to be filtered out.

# %%
def remove_stopwords(textual_data, status_logger_name):
	'''This function removes the standard set of stopwords from the corpus of abstract words'''
	remove_stopwords_start_status_key = "Removing stopwords"
	status_logger(status_logger_name, remove_stopwords_start_status_key)
	return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in textual_data]
	remove_stopwords_end_status_key = "Removed stopwords"
	status_logger(status_logger_name, remove_stopwords_end_status_key)

# %% [markdown]
# Generating the ```pyLDAvis``` visualization from the ```lda_model``` generated and trained on our ```corpus``` & ```id2word``` dictionary. The time taken here is proportional to the size of the ```corpus```.

# %%
def visualizer_generator(lda_model, corpus, id2word, logs_folder_name, status_logger_name):
	'''This code generates the .html file with generates the visualization of the data prepared.'''
	visualizer_generator_start_status_key = "Preparing the topic modeling visualization"
	status_logger(status_logger_name, visualizer_generator_start_status_key)
    
	textual_data_visualization = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
	pyLDAvis.save_html(textual_data_visualization, session_folder_name+'/'+"Data_Visualization_Topic_Modelling.html")

	visualizer_generator_end_status_key = "Prepared the topic modeling visualization"+" "+"Data_Visualization_Topic_Modelling.html"
	status_logger(status_logger_name, visualizer_generator_end_status_key)

# %% [markdown]
# Lemmatization involves truncating a term to its root term. For example *running -> run* is an example of the ```lemmatization``` process.

# %%
def lemmatization(status_logger_name, textual_data, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
	lemmatization_start_status_key = "Beginning lemmatization"
	status_logger(status_logger_name, lemmatization_start_status_key)
	"""https://spacy.io/api/annotation"""
	texts_out = []
	nlp = spacy.load('en', disable=['parser', 'ner'])
	for sent in textual_data:
		doc = nlp(" ".join(sent))
		texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
	lemmatization_end_status_key = "Ending lemmatization"
	status_logger(status_logger_name, lemmatization_end_status_key)
	return texts_out

# %% [markdown]
# Calling the ```nlp_engine_main()``` function where all the previously defined functions come together and generate the ```pyLDAvis``` visualization for topic analysis.

# %%
nlp_engine_main_start_status_key = "Initiating the NLP Engine"
status_logger(status_logger_name, nlp_engine_main_start_status_key)

'''Extracts the data from the .txt file and puts them into a Pandas dataframe buckets'''
textual_dataframe = data_reader(abstracts_log_name, status_logger_name)
'''Rids the symbols and special characters from the textual_data'''
textual_data = textual_data_trimmer(textual_dataframe, status_logger_name)
'''Removes stopwords that were earlier downloaded from the textual_data'''
textual_data_no_stops = remove_stopwords(textual_data, status_logger_name)
'''Prepares bigrams'''
textual_data_words_bigrams = make_bigrams(textual_data_no_stops, status_logger_name)
'''Loads the English model from spaCy'''
nlp = spacy.load('en', disable=['parser', 'ner'])

textual_data_lemmatized = lemmatization(status_logger_name, textual_data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

id2word = corpora.Dictionary(textual_data_lemmatized)

texts = textual_data_lemmatized
corpus = [id2word.doc2bow(text) for text in texts]

[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]

'''Builds the actual LDA model that will be used for the visualization and inference'''
lda_model = gensim.models.ldamodel.LdaModel(corpus = corpus, id2word = id2word, num_topics = 12, random_state = 100, update_every = 1, chunksize = 100, passes = 10, alpha = 'symmetric', per_word_topics = True)

doc_lda = lda_model[corpus]

perplexity_score = lda_model.log_perplexity(corpus)

perplexity_status_key = "Issued perplexity:"+" "+str(perplexity_score)

status_logger(status_logger_name, perplexity_status_key)

nlp_engine_main_end_status_key = "Idling the NLP Engine"
status_logger(status_logger_name, nlp_engine_main_end_status_key)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [INFO]17:52:12 Generating bigrams
# [INFO]17:52:12 Generating word bigrams
# [INFO]17:52:17 Generated word bigrams
# [INFO]17:52:19 Beginning lemmatization
# [INFO]17:52:40 Ending lemmatization
# [INFO]17:53:13 Issued perplexity: -9.42808103444275
# [INFO]17:53:13 Idling the NLP Engine

# %%
lda_model

# %% [markdown]
# Presenting the topics of the trained ```LDA``` model here.

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.070*"mammal" + 0.041*"urban" + 0.033*"standard" + 0.031*"extinct" + 0.022*"gene" + 0.019*"peninsula" + 0.018*"phylogenetic" + 0.018*"difficulty" + 0.017*"taxonomy" + 0.016*"carnivore"'),
#  (1,
#   '0.033*"hunt" + 0.031*"people" + 0.019*"systematic" + 0.017*"climate_change" + 0.017*"climate" + 0.016*"valley" + 0.015*"climatic" + 0.013*"description" + 0.013*"arise" + 0.013*"inadequate"'),
#  (2,
#   '0.053*"nutrient" + 0.044*"social" + 0.037*"flower" + 0.035*"pollen" + 0.022*"concentration" + 0.019*"semi_natural" + 0.015*"adoption" + 0.013*"trait" + 0.013*"competition" + 0.013*"fluctuation"'),
#  (3,
#   '0.040*"bird" + 0.024*"population" + 0.016*"year" + 0.016*"wildlife" + 0.016*"decline" + 0.013*"km" + 0.011*"wetland" + 0.011*"nest" + 0.010*"fire" + 0.010*"animal"'),
#  (4,
#   '0.030*"conservation" + 0.020*"biodiversity" + 0.009*"protect" + 0.008*"management" + 0.007*"resource" + 0.007*"base" + 0.007*"datum" + 0.006*"reserve" + 0.006*"information" + 0.006*"development"'),
#  (5,
#   '0.068*"soil" + 0.025*"microbial" + 0.023*"bacteria" + 0.022*"strain" + 0.021*"microorganism" + 0.016*"protozoa" + 0.015*"productivity" + 0.015*"pest" + 0.013*"edible" + 0.013*"disease"'),
#  (6,
#   '0.074*"endemic" + 0.063*"plant" + 0.059*"island" + 0.031*"butterfly" + 0.030*"taxa" + 0.027*"rare" + 0.026*"distribution" + 0.025*"flora" + 0.022*"region" + 0.017*"richness"'),
#  (7,
#   '0.036*"algae" + 0.029*"algal" + 0.028*"colonization" + 0.028*"bryophyte" + 0.025*"damage" + 0.024*"sediment" + 0.020*"frequent" + 0.019*"root" + 0.018*"overview" + 0.016*"benthic"'),
#  (8,
#   '0.190*"forest" + 0.055*"tree" + 0.017*"plot" + 0.015*"tropical" + 0.010*"primary" + 0.010*"density" + 0.009*"log" + 0.009*"fungi" + 0.008*"lichen" + 0.008*"secondary"'),
#  (9,
#   '0.075*"native" + 0.043*"plantation" + 0.041*"plant" + 0.031*"cultivate" + 0.025*"exotic" + 0.021*"invasion" + 0.019*"alien" + 0.016*"perennial" + 0.016*"crop" + 0.015*"seed_bank"'),
#  (10,
#   '0.051*"population" + 0.020*"genetic" + 0.019*"model" + 0.016*"estimate" + 0.016*"distribution" + 0.015*"seed" + 0.013*"number" + 0.012*"extinction" + 0.011*"river" + 0.010*"range"'),
#  (11,
#   '0.024*"diversity" + 0.024*"habitat" + 0.017*"site" + 0.014*"richness" + 0.013*"community" + 0.011*"plant" + 0.010*"number" + 0.009*"vegetation" + 0.007*"type" + 0.007*"increase"')]

# %% [markdown]
# Declaring the ```mallet``` path here. Part of the GitHub package that you've cloned.

# %%
mallet_path = '/home/sarthak/projects/Bias/mallet-2.0.8/bin/mallet'

# %% [markdown]
# Building the ```LDA mallet``` model here, to generate the representative documents, run the coherence tests and issue perplexity here.

# %%
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=12, id2word=id2word)

# %% [markdown]
# Just checking out the topics of the ```LDA mallet``` model here.

# %%
pprint(ldamallet.show_topics(formatted=False))
# Out:
# [(7,
#   [('plant', 0.06123378101525154),
#    ('native', 0.02842590484862281),
#    ('impact', 0.02449920327794218),
#    ('island', 0.021909856590029593),
#    ('natural', 0.017641702708854998),
#    ('human', 0.014369451399954472),
#    ('control', 0.014255633963123151),
#    ('insect', 0.011751650352834054),
#    ('restoration', 0.011495561119963579),
#    ('potential', 0.010101297518779877)]),
#  (10,
#   [('richness', 0.06920615165792515),
#    ('diversity', 0.06120544048359854),
#    ('community', 0.03764779091474798),
#    ('vegetation', 0.034358609654191484),
#    ('site', 0.03186949951106765),
#    ('plant', 0.020468486087652237),
#    ('abundance', 0.020357365099119923),
#    ('grassland', 0.01980176015645835),
#    ('composition', 0.01789047915370255),
#    ('group', 0.015556938394523958)]),
#  (2,
#   [('change', 0.043140889830508476),
#    ('increase', 0.03411016949152542),
#    ('time', 0.016366525423728812),
#    ('climate_change', 0.012447033898305085),
#    ('condition', 0.012420550847457627),
#    ('year', 0.01239406779661017),
#    ('show', 0.01239406779661017),
#    ('response', 0.012314618644067797),
#    ('effect', 0.011970338983050848),
#    ('ecosystem', 0.011758474576271187)]),
#  (0,
#   [('management', 0.022856463313116897),
#    ('local', 0.021952669758591985),
#    ('resource', 0.020216434772267807),
#    ('conservation', 0.016791532881436557),
#    ('development', 0.011463907717921275),
#    ('wildlife', 0.011416339636104174),
#    ('human', 0.009989297181591153),
#    ('practice', 0.00918063979070044),
#    ('benefit', 0.008847663217980735),
#    ('activity', 0.00858603876798668)]),
#  (11,
#   [('model', 0.03490759753593429),
#    ('datum', 0.025715104340766917),
#    ('distribution', 0.02289766486796237),
#    ('method', 0.01879088868726422),
#    ('base', 0.017979084093405283),
#    ('spatial', 0.017119526288142877),
#    ('analysis', 0.017024019865335943),
#    ('scale', 0.015233274437705936),
#    ('estimate', 0.014851248746478201),
#    ('result', 0.013705171672794995)]),
#  (9,
#   [('water', 0.014842036293194314),
#    ('river', 0.011252599492920833),
#    ('diversity', 0.011224111899267869),
#    ('taxa', 0.011053186337350083),
#    ('site', 0.010568897245249695),
#    ('assemblage', 0.010568897245249695),
#    ('community', 0.010483434464290802),
#    ('wetland', 0.01034099649602598),
#    ('host', 0.01019855852776116),
#    ('fish', 0.009714269435660769)]),
#  (8,
#   [('forest', 0.1583066005638184),
#    ('tree', 0.050573539418683776),
#    ('stand', 0.014411393020316904),
#    ('density', 0.012418586565568194),
#    ('plantation', 0.012394284047827355),
#    ('disturbance', 0.011349275784971323),
#    ('edge', 0.010984738018858754),
#    ('tropical', 0.010158452415670264),
#    ('composition', 0.009793914649557695),
#    ('plot', 0.00972100709633518)]),
#  (6,
#   [('habitat', 0.11125287701390973),
#    ('landscape', 0.04250475332732913),
#    ('land', 0.0273941759231462),
#    ('genetic', 0.020239167417192033),
#    ('effect', 0.01621134794356049),
#    ('patch', 0.014960472330631441),
#    ('agricultural', 0.013009106374462124),
#    ('important', 0.012008405884118884),
#    ('result', 0.011733213249274493),
#    ('butterfly', 0.011558090663464426)]),
#  (4,
#   [('population', 0.06486569770427816),
#    ('bird', 0.03510348723743002),
#    ('large', 0.015176416208720662),
#    ('rate', 0.015125057778234297),
#    ('individual', 0.013892455446561553),
#    ('density', 0.01255713625391608),
#    ('seed', 0.011863797442350162),
#    ('mammal', 0.011504288428945611),
#    ('number', 0.011452929998459246),
#    ('site', 0.011298854707000153)]),
#  (3,
#   [('conservation', 0.07559947938496835),
#    ('biodiversity', 0.06503275903906819),
#    ('approach', 0.015596390990712757),
#    ('research', 0.01438309324744656),
#    ('management', 0.013765414396329223),
#    ('strategy', 0.01312567558624341),
#    ('ecological', 0.01246387681718912),
#    ('process', 0.011846197966071783),
#    ('base', 0.010566720345900157),
#    ('target', 0.009882861617877391)])]

# %% [markdown]
# Presenting the "Coherence" of the model here. Coherence is a proxy for how well the model has been built and trained.

# %%
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=textual_data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# Coherence Score:  0.44606323441255064

# %% [markdown]
# Presenting the coherence here for a bunch of trained models. Will be eventually selecting the ```optimal_model``` as the ```lda_model```, to get the representative documents with corresponding ```num_topics```.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# %% [markdown]
# Computing coherence from the previously generated ```mallet``` models, to find the model with the best coherence, and thereby the best model.

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=textual_data_lemmatized, start=2, limit=40, step=6)

# %% [markdown]
# Plotting the computed coherence scores here for the models that we generated.

# %%
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# Declaring the ```optimal_model``` as the previously generated ```ldamallet``` model.

# %%
optimal_model = ldamallet

# %% [markdown]
# Presenting the topics of the ```ldamallet``` model here.

# %%
model_topics = optimal_model.show_topics(formatted=False)
print(model_topics)
# Out:
# [(1, [('region', 0.03950226128727291), ('area', 0.03549071211385645), ('endemic', 0.022996141758438306), ('distribution', 0.02243401384878759), ('reserve', 0.01852466974985308), ('protect', 0.017374862661931164), ('number', 0.01476863326264149), ('total', 0.014462018039195647), ('rare', 0.01443646677057516), ('pattern', 0.013695479980581036)]), (6, [('habitat', 0.11125287701390973), ('landscape', 0.04250475332732913), ('land', 0.0273941759231462), ('genetic', 0.020239167417192033), ('effect', 0.01621134794356049), ('patch', 0.014960472330631441), ('agricultural', 0.013009106374462124), ('important', 0.012008405884118884), ('result', 0.011733213249274493), ('butterfly', 0.011558090663464426)]), (8, [('forest', 0.1583066005638184), ('tree', 0.050573539418683776), ('stand', 0.014411393020316904), ('density', 0.012418586565568194), ('plantation', 0.012394284047827355), ('disturbance', 0.011349275784971323), ('edge', 0.010984738018858754), ('tropical', 0.010158452415670264), ('composition', 0.009793914649557695), ('plot', 0.00972100709633518)]), (2, [('change', 0.043140889830508476), ('increase', 0.03411016949152542), ('time', 0.016366525423728812), ('climate_change', 0.012447033898305085), ('condition', 0.012420550847457627), ('year', 0.01239406779661017), ('show', 0.01239406779661017), ('response', 0.012314618644067797), ('effect', 0.011970338983050848), ('ecosystem', 0.011758474576271187)]), (9, [('water', 0.014842036293194314), ('river', 0.011252599492920833), ('diversity', 0.011224111899267869), ('taxa', 0.011053186337350083), ('site', 0.010568897245249695), ('assemblage', 0.010568897245249695), ('community', 0.010483434464290802), ('wetland', 0.01034099649602598), ('host', 0.01019855852776116), ('fish', 0.009714269435660769)]), (7, [('plant', 0.06123378101525154), ('native', 0.02842590484862281), ('impact', 0.02449920327794218), ('island', 0.021909856590029593), ('natural', 0.017641702708854998), ('human', 0.014369451399954472), ('control', 0.014255633963123151), ('insect', 0.011751650352834054), ('restoration', 0.011495561119963579), ('potential', 0.010101297518779877)]), (10, [('richness', 0.06920615165792515), ('diversity', 0.06120544048359854), ('community', 0.03764779091474798), ('vegetation', 0.034358609654191484), ('site', 0.03186949951106765), ('plant', 0.020468486087652237), ('abundance', 0.020357365099119923), ('grassland', 0.01980176015645835), ('composition', 0.01789047915370255), ('group', 0.015556938394523958)]), (11, [('model', 0.03490759753593429), ('datum', 0.025715104340766917), ('distribution', 0.02289766486796237), ('method', 0.01879088868726422), ('base', 0.017979084093405283), ('spatial', 0.017119526288142877), ('analysis', 0.017024019865335943), ('scale', 0.015233274437705936), ('estimate', 0.014851248746478201), ('result', 0.013705171672794995)]), (0, [('management', 0.022856463313116897), ('local', 0.021952669758591985), ('resource', 0.020216434772267807), ('conservation', 0.016791532881436557), ('development', 0.011463907717921275), ('wildlife', 0.011416339636104174), ('human', 0.009989297181591153), ('practice', 0.00918063979070044), ('benefit', 0.008847663217980735), ('activity', 0.00858603876798668)]), (5, [('conservation', 0.03196285398050914), ('threaten', 0.024809005750074237), ('threat', 0.01635936614205113), ('datum', 0.015549496531058499), ('status', 0.013551818157276678), ('extinction', 0.012903922468482574), ('endanger', 0.012418000701886997), ('include', 0.012418000701886997), ('global', 0.011824096320492401), ('current', 0.011743109359393138)])]

# %% [markdown]
# ```num_words``` dictates the number of keywords to be presented with each topic.

# %%
pprint(optimal_model.print_topics(num_words=40))
# Out:
# [(0,
#   '0.023*"management" + 0.022*"local" + 0.020*"resource" + '
#   '0.017*"conservation" + 0.011*"development" + 0.011*"wildlife" + '
#   '0.010*"human" + 0.009*"practice" + 0.009*"benefit" + 0.009*"activity" + '
#   '0.008*"community" + 0.008*"economic" + 0.008*"people" + 0.008*"traditional" '
#   '+ 0.008*"policy" + 0.007*"protect" + 0.007*"support" + 0.007*"nature" + '
#   '0.006*"wild" + 0.006*"farm" + 0.006*"natural" + 0.006*"conflict" + '
#   '0.006*"sustainable" + 0.006*"park" + 0.006*"develop" + 0.006*"crop" + '
#   '0.005*"social" + 0.005*"land" + 0.005*"harvest" + 0.005*"environmental" + '
#   '0.005*"involve" + 0.005*"production" + 0.005*"programme" + 0.004*"public" + '
#   '0.004*"state" + 0.004*"make" + 0.004*"cultural" + 0.004*"farmer" + '
#   '0.004*"project" + 0.004*"promote"'),
#  (1,
#   '0.040*"region" + 0.035*"area" + 0.023*"endemic" + 0.022*"distribution" + '
#   '0.019*"reserve" + 0.017*"protect" + 0.015*"number" + 0.014*"total" + '
#   '0.014*"rare" + 0.014*"pattern" + 0.013*"record" + 0.013*"taxa" + '
#   '0.013*"range" + 0.012*"represent" + 0.011*"family" + 0.010*"hotspot" + '
#   '0.010*"high" + 0.010*"flora" + 0.010*"identify" + 0.009*"southern" + '
#   '0.008*"mountain" + 0.008*"occur" + 0.008*"analysis" + 0.007*"northern" + '
#   '0.007*"important" + 0.007*"endemism" + 0.007*"locate" + 0.007*"western" + '
#   '0.007*"restrict" + 0.007*"eastern" + 0.006*"rich" + 0.006*"central" + '
#   '0.006*"genera" + 0.006*"show" + 0.006*"south" + 0.006*"level" + '
#   '0.006*"include" + 0.005*"north" + 0.005*"state" + 0.005*"rarity"'),
#  (2,
#   '0.043*"change" + 0.034*"increase" + 0.016*"time" + 0.012*"climate_change" + '
#   '0.012*"condition" + 0.012*"year" + 0.012*"show" + 0.012*"response" + '
#   '0.012*"effect" + 0.012*"ecosystem" + 0.011*"decline" + 0.010*"fire" + '
#   '0.010*"climate" + 0.010*"decrease" + 0.009*"trait" + 0.008*"soil" + '
#   '0.008*"future" + 0.008*"disturbance" + 0.008*"dynamic" + 0.008*"impact" + '
#   '0.007*"temperature" + 0.007*"trend" + 0.007*"climatic" + 0.007*"period" + '
#   '0.007*"environmental" + 0.007*"influence" + 0.006*"long_term" + '
#   '0.006*"significant" + 0.006*"burn" + 0.006*"shift" + 0.006*"dry" + '
#   '0.006*"range" + 0.005*"affect" + 0.005*"observe" + 0.005*"result" + '
#   '0.005*"follow" + 0.005*"factor" + 0.005*"loss" + 0.005*"lead" + '
#   '0.005*"long"'),
#  (3,
#   '0.076*"conservation" + 0.065*"biodiversity" + 0.016*"approach" + '
#   '0.014*"research" + 0.014*"management" + 0.013*"strategy" + '
#   '0.012*"ecological" + 0.012*"process" + 0.011*"base" + 0.010*"target" + '
#   '0.010*"monitoring" + 0.009*"knowledge" + 0.008*"protect" + 0.008*"propose" '
#   '+ 0.007*"focus" + 0.007*"assessment" + 0.007*"system" + 0.007*"review" + '
#   '0.007*"plan" + 0.007*"monitor" + 0.006*"scientific" + 0.006*"priority" + '
#   '0.006*"identify" + 0.006*"develop" + 0.006*"tool" + 0.006*"paper" + '
#   '0.006*"effective" + 0.006*"require" + 0.006*"criterion" + '
#   '0.006*"biological" + 0.006*"ecosystem_service" + 0.005*"aim" + '
#   '0.005*"ecosystem" + 0.005*"address" + 0.005*"level" + 0.005*"framework" + '
#   '0.005*"network" + 0.005*"planning" + 0.005*"objective" + 0.005*"include"'),
#  (4,
#   '0.065*"population" + 0.035*"bird" + 0.015*"large" + 0.015*"rate" + '
#   '0.014*"individual" + 0.013*"density" + 0.012*"seed" + 0.012*"mammal" + '
#   '0.011*"number" + 0.011*"site" + 0.010*"abundance" + 0.009*"nest" + '
#   '0.009*"decline" + 0.008*"size" + 0.008*"bat" + 0.007*"suggest" + '
#   '0.007*"road" + 0.006*"high" + 0.006*"survey" + 0.006*"capture" + '
#   '0.006*"survival" + 0.006*"year" + 0.006*"breeding" + 0.005*"flower" + '
#   '0.005*"season" + 0.005*"common" + 0.005*"increase" + 0.005*"range" + '
#   '0.005*"mortality" + 0.005*"carnivore" + 0.004*"breed" + 0.004*"period" + '
#   '0.004*"human" + 0.004*"adult" + 0.004*"prey" + 0.004*"animal" + '
#   '0.004*"forage" + 0.004*"compare" + 0.004*"winter" + 0.004*"low"'),
#  (5,
#   '0.032*"conservation" + 0.025*"threaten" + 0.016*"threat" + 0.016*"datum" + '
#   '0.014*"status" + 0.013*"extinction" + 0.012*"endanger" + 0.012*"include" + '
#   '0.012*"global" + 0.012*"current" + 0.011*"collection" + 0.011*"list" + '
#   '0.011*"country" + 0.010*"information" + 0.010*"survey" + 0.009*"assess" + '
#   '0.009*"protection" + 0.008*"effort" + 0.008*"world" + 0.008*"present" + '
#   '0.007*"european" + 0.007*"collect" + 0.007*"recent" + 0.007*"group" + '
#   '0.007*"taxonomic" + 0.006*"exist" + 0.006*"report" + 0.006*"record" + '
#   '0.006*"assessment" + 0.006*"large" + 0.006*"national" + 0.006*"make" + '
#   '0.006*"biological" + 0.006*"result" + 0.006*"risk" + 0.006*"category" + '
#   '0.005*"concern" + 0.005*"europe" + 0.005*"inventory" + 0.005*"remain"'),
#  (6,
#   '0.111*"habitat" + 0.043*"landscape" + 0.027*"land" + 0.020*"genetic" + '
#   '0.016*"effect" + 0.015*"patch" + 0.013*"agricultural" + 0.012*"important" + '
#   '0.012*"result" + 0.012*"butterfly" + 0.011*"structure" + 0.010*"large" + '
#   '0.010*"area" + 0.009*"increase" + 0.009*"loss" + 0.009*"urban" + '
#   '0.009*"quality" + 0.009*"fragmentation" + 0.009*"associate" + 0.008*"type" '
#   '+ 0.008*"diversity" + 0.008*"distance" + 0.008*"scale" + 0.008*"size" + '
#   '0.008*"level" + 0.007*"specialist" + 0.007*"maintain" + 0.007*"show" + '
#   '0.007*"fragment" + 0.007*"surround" + 0.007*"influence" + 0.006*"matrix" + '
#   '0.006*"remnant" + 0.006*"presence" + 0.006*"factor" + 0.006*"suggest" + '
#   '0.006*"investigate" + 0.005*"connectivity" + 0.005*"affect" + '
#   '0.005*"occurrence"'),
#  (7,
#   '0.061*"plant" + 0.028*"native" + 0.024*"impact" + 0.022*"island" + '
#   '0.018*"natural" + 0.014*"human" + 0.014*"control" + 0.012*"insect" + '
#   '0.011*"restoration" + 0.010*"potential" + 0.010*"ecosystem" + 0.010*"great" '
#   '+ 0.009*"invasive" + 0.008*"suggest" + 0.008*"establish" + '
#   '0.008*"ecological" + 0.008*"result" + 0.007*"important" + 0.007*"effect" + '
#   '0.007*"support" + 0.007*"introduce" + 0.007*"reduce" + 0.007*"alien" + '
#   '0.007*"invasion" + 0.006*"exotic" + 0.006*"role" + 0.006*"biodiversity" + '
#   '0.006*"introduction" + 0.005*"include" + 0.005*"treatment" + '
#   '0.005*"evidence" + 0.005*"animal" + 0.005*"system" + 0.005*"play" + '
#   '0.005*"dispersal" + 0.005*"establishment" + 0.005*"herbivore" + '
#   '0.004*"present" + 0.004*"activity" + 0.004*"negative"'),
#  (8,
#   '0.158*"forest" + 0.051*"tree" + 0.014*"stand" + 0.012*"density" + '
#   '0.012*"plantation" + 0.011*"disturbance" + 0.011*"edge" + 0.010*"tropical" '
#   '+ 0.010*"composition" + 0.010*"plot" + 0.010*"high" + 0.008*"structure" + '
#   '0.008*"primary" + 0.008*"cover" + 0.007*"compare" + 0.007*"fragment" + '
#   '0.007*"log" + 0.007*"type" + 0.007*"diversity" + 0.006*"individual" + '
#   '0.006*"large" + 0.006*"site" + 0.006*"woodland" + 0.006*"canopy" + '
#   '0.006*"secondary" + 0.006*"low" + 0.006*"number" + 0.006*"manage" + '
#   '0.006*"lichen" + 0.006*"dominate" + 0.005*"wood" + 0.005*"disturb" + '
#   '0.005*"age" + 0.005*"study" + 0.005*"natural" + 0.005*"total" + '
#   '0.004*"beetle" + 0.004*"mature" + 0.004*"significantly" + 0.004*"great"'),
#  (9,
#   '0.015*"water" + 0.011*"river" + 0.011*"diversity" + 0.011*"taxa" + '
#   '0.011*"site" + 0.011*"assemblage" + 0.010*"community" + 0.010*"wetland" + '
#   '0.010*"host" + 0.010*"fish" + 0.010*"sample" + 0.009*"invertebrate" + '
#   '0.009*"marine" + 0.008*"group" + 0.008*"level" + 0.008*"environment" + '
#   '0.008*"number" + 0.007*"collect" + 0.007*"coastal" + 0.007*"organism" + '
#   '0.007*"aquatic" + 0.007*"include" + 0.006*"riparian" + 0.006*"associate" + '
#   '0.006*"stream" + 0.006*"pond" + 0.006*"occur" + 0.005*"important" + '
#   '0.005*"freshwater" + 0.005*"zone" + 0.005*"terrestrial" + 0.005*"fauna" + '
#   '0.005*"total" + 0.005*"show" + 0.005*"lake" + 0.005*"diverse" + '
#   '0.005*"order" + 0.005*"fungi" + 0.005*"describe" + 0.005*"specific"'),
#  (10,
#   '0.069*"richness" + 0.061*"diversity" + 0.038*"community" + '
#   '0.034*"vegetation" + 0.032*"site" + 0.020*"plant" + 0.020*"abundance" + '
#   '0.020*"grassland" + 0.018*"composition" + 0.016*"group" + 0.014*"type" + '
#   '0.012*"significantly" + 0.011*"cover" + 0.011*"sample" + 0.011*"high" + '
#   '0.010*"ant" + 0.010*"soil" + 0.010*"difference" + 0.009*"functional" + '
#   '0.009*"gradient" + 0.009*"indicator" + 0.007*"relationship" + 0.007*"show" '
#   '+ 0.007*"effect" + 0.007*"assemblage" + 0.007*"significant" + '
#   '0.007*"pattern" + 0.007*"structure" + 0.006*"shrub" + 0.006*"correlate" + '
#   '0.006*"plot" + 0.006*"influence" + 0.006*"arthropod" + 0.006*"variable" + '
#   '0.006*"heterogeneity" + 0.005*"pasture" + 0.005*"explain" + 0.005*"affect" '
#   '+ 0.005*"differ" + 0.005*"index"'),
#  (11,
#   '0.035*"model" + 0.026*"datum" + 0.023*"distribution" + 0.019*"method" + '
#   '0.018*"base" + 0.017*"spatial" + 0.017*"analysis" + 0.015*"scale" + '
#   '0.015*"estimate" + 0.014*"result" + 0.012*"environmental" + '
#   '0.012*"variable" + 0.012*"predict" + 0.011*"index" + 0.010*"identify" + '
#   '0.010*"sample" + 0.009*"pattern" + 0.008*"survey" + 0.008*"assess" + '
#   '0.008*"field" + 0.008*"good" + 0.007*"select" + 0.007*"map" + 0.007*"test" '
#   '+ 0.007*"potential" + 0.007*"occurrence" + 0.007*"range" + '
#   '0.006*"technique" + 0.006*"evaluate" + 0.006*"apply" + 0.006*"factor" + '
#   '0.006*"compare" + 0.006*"measure" + 0.006*"suitable" + 0.005*"determine" + '
#   '0.005*"obtain" + 0.005*"information" + 0.005*"analyse" + 0.005*"set" + '
#   '0.005*"regional"')]

# %% [markdown]
# This function computes the dominant topic in each sentence. We use this meta-data as a part of our framework to understand under which areas of research do the publications fall in, and also to label each of the ```pyLDAvis``` topics.

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=textual_data):
    sent_topics_df = pd.DataFrame()
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %% [markdown]
# Generating the ```dataframes``` here which contains the dominant topics for each abstract.

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=textual_data)
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0             2.0              0.2686
# 1               1             2.0              0.2830
# 2               2             2.0              0.3445
# 3               3            11.0              0.3352
# 4               4            10.0              0.2759
# 5               5             2.0              0.3207
# 6               6             2.0              0.3324
# 7               7             7.0              0.4285
# 8               8             2.0              0.5869
# 9               9             2.0              0.3314
# 10             10            11.0              0.3149
# 11             11             5.0              0.2676
# 12             12             2.0              0.3542
# 13             13            11.0              0.3948
# 14             14             2.0              0.3703
# 15             15            10.0              0.2305
# 16             16             2.0              0.3303
# 17             17             2.0              0.3018
# 18             18             2.0              0.2784
# 19             19             2.0              0.3661
# 20             20             2.0              0.2778
# 21             21             2.0              0.2830
# 22             22             2.0              0.3458
# 23             23            11.0              0.3420
# 24             24            10.0              0.2921
# 25             25             2.0              0.3227
# 26             26             2.0              0.3324
# 27             27             7.0              0.4408
# 28             28             2.0              0.5891
# 29             29             2.0              0.3214
# ...           ...             ...                 ...
# 4703         4703            11.0              0.1981
# 4704         4704             9.0              0.1286
# 4705         4705             0.0              0.0833
# 4706         4706             0.0              0.0833
# 4707         4707             9.0              0.2249
# 4708         4708             9.0              0.1617
# 4709         4709             0.0              0.0833
# 4710         4710             0.0              0.0833
# 4711         4711             9.0              0.2714
# 4712         4712             9.0              0.1419
# 4713         4713             9.0              0.1582
# 4714         4714             9.0              0.2950
# 4715         4715             9.0              0.3533
# 4716         4716             3.0              0.1651
# 4717         4717             9.0              0.2521
# 4718         4718             3.0              0.2622
# 4719         4719             9.0              0.2813
# 4720         4720             0.0              0.0833
# 4721         4721             0.0              0.0833
# 4722         4722             0.0              0.0833
# 4723         4723            10.0              0.1951
# 4724         4724             3.0              0.1758
# 4725         4725             1.0              0.1834
# 4726         4726             0.0              0.4366
# 4727         4727             7.0              0.2926
# 4728         4728             0.0              0.0833
# 4729         4729             9.0              0.2102
# 4730         4730             5.0              0.3006
# 4731         4731             1.0              0.2045
# 4732         4732             7.0              0.1965
#
#                                                Keywords  \
# 0     change, increase, time, climate_change, condit...
# 1     change, increase, time, climate_change, condit...
# 2     change, increase, time, climate_change, condit...
# 3     model, datum, distribution, method, base, spat...
# 4     richness, diversity, community, vegetation, si...
# 5     change, increase, time, climate_change, condit...
# 6     change, increase, time, climate_change, condit...
# 7     plant, native, impact, island, natural, human,...
# 8     change, increase, time, climate_change, condit...
# 9     change, increase, time, climate_change, condit...
# 10    model, datum, distribution, method, base, spat...
# 11    conservation, threaten, threat, datum, status,...
# 12    change, increase, time, climate_change, condit...
# 13    model, datum, distribution, method, base, spat...
# 14    change, increase, time, climate_change, condit...
# 15    richness, diversity, community, vegetation, si...
# 16    change, increase, time, climate_change, condit...
# 17    change, increase, time, climate_change, condit...
# 18    change, increase, time, climate_change, condit...
# 19    change, increase, time, climate_change, condit...
# 20    change, increase, time, climate_change, condit...
# 21    change, increase, time, climate_change, condit...
# 22    change, increase, time, climate_change, condit...
# 23    model, datum, distribution, method, base, spat...
# 24    richness, diversity, community, vegetation, si...
# 25    change, increase, time, climate_change, condit...
# 26    change, increase, time, climate_change, condit...
# 27    plant, native, impact, island, natural, human,...
# 28    change, increase, time, climate_change, condit...
# 29    change, increase, time, climate_change, condit...
# ...                                                 ...
# 4703  model, datum, distribution, method, base, spat...
# 4704  water, river, diversity, taxa, site, assemblag...
# 4705  management, local, resource, conservation, dev...
# 4706  management, local, resource, conservation, dev...
# 4707  water, river, diversity, taxa, site, assemblag...
# 4708  water, river, diversity, taxa, site, assemblag...
# 4709  management, local, resource, conservation, dev...
# 4710  management, local, resource, conservation, dev...
# 4711  water, river, diversity, taxa, site, assemblag...
# 4712  water, river, diversity, taxa, site, assemblag...
# 4713  water, river, diversity, taxa, site, assemblag...
# 4714  water, river, diversity, taxa, site, assemblag...
# 4715  water, river, diversity, taxa, site, assemblag...
# 4716  conservation, biodiversity, approach, research...
# 4717  water, river, diversity, taxa, site, assemblag...
# 4718  conservation, biodiversity, approach, research...
# 4719  water, river, diversity, taxa, site, assemblag...
# 4720  management, local, resource, conservation, dev...
# 4721  management, local, resource, conservation, dev...
# 4722  management, local, resource, conservation, dev...
# 4723  richness, diversity, community, vegetation, si...
# 4724  conservation, biodiversity, approach, research...
# 4725  region, area, endemic, distribution, reserve, ...
# 4726  management, local, resource, conservation, dev...
# 4727  plant, native, impact, island, natural, human,...
# 4728  management, local, resource, conservation, dev...
# 4729  water, river, diversity, taxa, site, assemblag...
# 4730  conservation, threaten, threat, datum, status,...
# 4731  region, area, endemic, distribution, reserve, ...
# 4732  plant, native, impact, island, natural, human,...
#
#                                                    Text
# 0     [Abstract: 'Maintenance of soil health is cent...
# 1     [Abstract: 'Plant invasion is highly responsiv...
# 2     [Abstract: 'Globally, treeline in mountain lan...
# 3     [Abstract: 'Forests play a crucial role by reg...
# 4     [Abstract: 'The analysis of species distributi...
# 5     [Abstract: 'The Himalayan ecosystem is one of ...
# 6     [Abstract: 'In an era of climate change, predi...
# 7     [Abstract: 'The relationship and its key predi...
# 8     [Abstract: 'Climate change effects on Himalaya...
# 9     [Abstract: 'With the threats of climate change...
# 10    [Abstract: 'The variation hypothesis assumes s...
# 11    [Abstract: 'The evolutionary success of a spec...
# 12    [Abstract: 'The current study focuses on the i...
# 13    [Abstract: 'The objective of this research is ...
# 14    [Abstract: 'Global warming is causing shifts i...
# 15    [Abstract: 'The geographical patterns of speci...
# 16    [Abstract: 'Himalaya is endowed with a great d...
# 17    [Abstract: 'Globally, the increase in the clim...
# 18    [Abstract: 'Climate change enhances invasive s...
# 19    [Abstract: 'This study adopts a twofold strate...
# 20    [Abstract: 'Maintenance of soil health is cent...
# 21    [Abstract: 'Plant invasion is highly responsiv...
# 22    [Abstract: 'Globally, treeline in mountain lan...
# 23    [Abstract: 'Forests play a crucial role by reg...
# 24    [Abstract: 'The analysis of species distributi...
# 25    [Abstract: 'The Himalayan ecosystem is one of ...
# 26    [Abstract: 'In an era of climate change, predi...
# 27    [Abstract: 'The relationship and its key predi...
# 28    [Abstract: 'Climate change effects on Himalaya...
# 29    [Abstract: 'With the threats of climate change...
# ...                                                 ...
# 4703  [Abstract: 'The ability of trees to migrate in...
# 4704  [Abstract: 'The soil Coleoptera community was ...
# 4705                 [Abstract: Abstract not available]
# 4706                 [Abstract: Abstract not available]
# 4707  [Abstract: 'The species concept is applicable ...
# 4708  [Abstract: "Concluding remarks from the joint ...
# 4709                 [Abstract: Abstract not available]
# 4710                 [Abstract: Abstract not available]
# 4711  [Abstract: 'Diversities in fungi are manifold....
# 4712  [Abstract: 'In the framework of initiatives, a...
# 4713  [Abstract: 'A short overview of the biodiversi...
# 4714  [Abstract: 'Nucleic acid probes have revolutio...
# 4715  [Abstract: "Algae are ubiquitous. They are the...
# 4716  [Abstract: 'Global biodiversity in lichens is ...
# 4717  [Abstract: 'The unicellular eukaryotes are cur...
# 4718  [Abstract: 'An introduction to, and the Action...
# 4719  [Abstract: 'The distribution of rhizobia, bact...
# 4720                 [Abstract: Abstract not available]
# 4721                 [Abstract: Abstract not available]
# 4722                 [Abstract: Abstract not available]
# 4723  [Abstract: "From 1985 through 1990, the herpet...
# 4724  [Abstract: "Europe's five species ofMaculinea ...
# 4725  [Abstract: 'The montane (low- to mid-alpine) z...
# 4726  [Abstract: 'The economic viability of the wild...
# 4727  [Abstract: "On the basis of botanical and ecol...
# 4728                 [Abstract: Abstract not available]
# 4729  [Abstract: 'Biodiversity is undisturbed rhithr...
# 4730  [Abstract: 'Given the widespread belief that t...
# 4731  [Abstract: 'Heathlands, dominated byCalluna vu...
# 4732  [Abstract: 'Sandeels, especiallyAmmodytes mari...
#
# [4733 rows x 5 columns]

# %% [markdown]
# Saving the ```dataframe``` to disc for analysis.

# %%
df_dominant_topic.to_csv(session_folder_name+'/Master_Topic_Per_Centence.csv')

# %% [markdown]
# Here we find the most representative document for each topic, and contain it in a ```dataframe``` and save it as a ```.csv```

# %%
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], axis=0)

# %%
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]
sent_topics_sorteddf_mallet.head()
sent_topics_sorteddf_mallet.to_csv(session_folder_name+'/Master_Topics_Contribution.csv')

# %% [markdown]
# Here, we find the number of documents for each topic.

# %%
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# %% [markdown]
# Here, we find the percentage of documents falling under each topic.

# %%
topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# %% [markdown]
# Presenting the dominant topics in each sentence here.

# %%
df_dominant_topics
# Out:
#       Dominant_Topic                                     Topic_Keywords  \
# 0                2.0  change, increase, time, climate_change, condit...
# 1                2.0  change, increase, time, climate_change, condit...
# 2                2.0  change, increase, time, climate_change, condit...
# 3               11.0  model, datum, distribution, method, base, spat...
# 4               10.0  richness, diversity, community, vegetation, si...
# 5                2.0  change, increase, time, climate_change, condit...
# 6                2.0  change, increase, time, climate_change, condit...
# 7                7.0  plant, native, impact, island, natural, human,...
# 8                2.0  change, increase, time, climate_change, condit...
# 9                2.0  change, increase, time, climate_change, condit...
# 10              11.0  model, datum, distribution, method, base, spat...
# 11               5.0  conservation, threaten, threat, datum, status,...
# 12               2.0  change, increase, time, climate_change, condit...
# 13              11.0  model, datum, distribution, method, base, spat...
# 14               2.0  change, increase, time, climate_change, condit...
# 15              10.0  richness, diversity, community, vegetation, si...
# 16               2.0  change, increase, time, climate_change, condit...
# 17               2.0  change, increase, time, climate_change, condit...
# 18               2.0  change, increase, time, climate_change, condit...
# 19               2.0  change, increase, time, climate_change, condit...
# 20               2.0  change, increase, time, climate_change, condit...
# 21               2.0  change, increase, time, climate_change, condit...
# 22               2.0  change, increase, time, climate_change, condit...
# 23              11.0  model, datum, distribution, method, base, spat...
# 24              10.0  richness, diversity, community, vegetation, si...
# 25               2.0  change, increase, time, climate_change, condit...
# 26               2.0  change, increase, time, climate_change, condit...
# 27               7.0  plant, native, impact, island, natural, human,...
# 28               2.0  change, increase, time, climate_change, condit...
# 29               2.0  change, increase, time, climate_change, condit...
# ...              ...                                                ...
# 4703            11.0  model, datum, distribution, method, base, spat...
# 4704             9.0  water, river, diversity, taxa, site, assemblag...
# 4705             0.0  management, local, resource, conservation, dev...
# 4706             0.0  management, local, resource, conservation, dev...
# 4707             9.0  water, river, diversity, taxa, site, assemblag...
# 4708             9.0  water, river, diversity, taxa, site, assemblag...
# 4709             0.0  management, local, resource, conservation, dev...
# 4710             0.0  management, local, resource, conservation, dev...
# 4711             9.0  water, river, diversity, taxa, site, assemblag...
# 4712             9.0  water, river, diversity, taxa, site, assemblag...
# 4713             9.0  water, river, diversity, taxa, site, assemblag...
# 4714             9.0  water, river, diversity, taxa, site, assemblag...
# 4715             9.0  water, river, diversity, taxa, site, assemblag...
# 4716             3.0  conservation, biodiversity, approach, research...
# 4717             9.0  water, river, diversity, taxa, site, assemblag...
# 4718             3.0  conservation, biodiversity, approach, research...
# 4719             9.0  water, river, diversity, taxa, site, assemblag...
# 4720             0.0  management, local, resource, conservation, dev...
# 4721             0.0  management, local, resource, conservation, dev...
# 4722             0.0  management, local, resource, conservation, dev...
# 4723            10.0  richness, diversity, community, vegetation, si...
# 4724             3.0  conservation, biodiversity, approach, research...
# 4725             1.0  region, area, endemic, distribution, reserve, ...
# 4726             0.0  management, local, resource, conservation, dev...
# 4727             7.0  plant, native, impact, island, natural, human,...
# 4728             0.0  management, local, resource, conservation, dev...
# 4729             9.0  water, river, diversity, taxa, site, assemblag...
# 4730             5.0  conservation, threaten, threat, datum, status,...
# 4731             1.0  region, area, endemic, distribution, reserve, ...
# 4732             7.0  plant, native, impact, island, natural, human,...
#
#       Num_Documents  Perc_Documents
# 0             783.0          0.1654
# 1             340.0          0.0718
# 2             262.0          0.0554
# 3             438.0          0.0925
# 4             376.0          0.0794
# 5             267.0          0.0564
# 6             318.0          0.0672
# 7             250.0          0.0528
# 8             502.0          0.1061
# 9             373.0          0.0788
# 10            452.0          0.0955
# 11            372.0          0.0786
# 12              NaN             NaN
# 13              NaN             NaN
# 14              NaN             NaN
# 15              NaN             NaN
# 16              NaN             NaN
# 17              NaN             NaN
# 18              NaN             NaN
# 19              NaN             NaN
# 20              NaN             NaN
# 21              NaN             NaN
# 22              NaN             NaN
# 23              NaN             NaN
# 24              NaN             NaN
# 25              NaN             NaN
# 26              NaN             NaN
# 27              NaN             NaN
# 28              NaN             NaN
# 29              NaN             NaN
# ...             ...             ...
# 4703            NaN             NaN
# 4704            NaN             NaN
# 4705            NaN             NaN
# 4706            NaN             NaN
# 4707            NaN             NaN
# 4708            NaN             NaN
# 4709            NaN             NaN
# 4710            NaN             NaN
# 4711            NaN             NaN
# 4712            NaN             NaN
# 4713            NaN             NaN
# 4714            NaN             NaN
# 4715            NaN             NaN
# 4716            NaN             NaN
# 4717            NaN             NaN
# 4718            NaN             NaN
# 4719            NaN             NaN
# 4720            NaN             NaN
# 4721            NaN             NaN
# 4722            NaN             NaN
# 4723            NaN             NaN
# 4724            NaN             NaN
# 4725            NaN             NaN
# 4726            NaN             NaN
# 4727            NaN             NaN
# 4728            NaN             NaN
# 4729            NaN             NaN
# 4730            NaN             NaN
# 4731            NaN             NaN
# 4732            NaN             NaN
#
# [4733 rows x 4 columns]

# %% [markdown]
# Saving it to a ```.csv``` bucket here.

# %%
df_dominant_topics.to_csv(session_folder_name+'/Master_Topics.csv')

# %% [markdown]
# Generating the visualization here from the ```lda_model```. We use this to label the broad areas of research, in syn which the representative documents generated above.

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
# Out:
# /home/sarthak/.local/lib/python3.5/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# Enabling the visualizations in the notebook here.

# %%
pyLDAvis.enable_notebook()

# %% [markdown]
# Saving the visualization to the disk, as an ```.html``` file in the sessions folder.

# %%
pyLDAvis.save_html(vis, session_folder_name+'/Master.html')

# %% [markdown]
# Presenting the ```pyLDAvis``` visualization here.

# %%
vis
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 11     37.817173        1       1 -0.317037  0.031738
# 4      31.456345        1       2 -0.297546  0.107870
# 10      8.202921        1       3 -0.204476 -0.055713
# 8       7.000277        1       4 -0.111004 -0.238273
# 3       5.913970        1       5 -0.097848  0.227758
# 6       2.851634        1       6 -0.001512 -0.232949
# 1       1.653463        1       7  0.148263  0.068872
# 9       1.638315        1       8  0.150440 -0.018081
# 5       1.173970        1       9  0.150620  0.053983
# 0       1.014442        1      10  0.185774  0.015144
# 7       0.663275        1      11  0.197799  0.018059
# 2       0.614215        1      12  0.196526  0.021592, topic_info=      Category         Freq            Term        Total  loglift  logprob
# 374    Default  6696.000000          forest  6696.000000  30.0000  30.0000
# 13618  Default  3265.000000           plant  3265.000000  29.0000  29.0000
# 5831   Default  2826.000000      population  2826.000000  28.0000  28.0000
# 17813  Default  1942.000000            tree  1942.000000  27.0000  27.0000
# 22518  Default  5196.000000    conservation  5196.000000  26.0000  26.0000
# 18518  Default  3049.000000        richness  3049.000000  25.0000  25.0000
# 6926   Default  1030.000000            soil  1030.000000  24.0000  24.0000
# 11322  Default  1061.000000         endemic  1061.000000  23.0000  23.0000
# 18191  Default  1197.000000            bird  1197.000000  22.0000  22.0000
# 603    Default  4824.000000         habitat  4824.000000  21.0000  21.0000
# 10128  Default  4765.000000       diversity  4765.000000  20.0000  20.0000
# 15531  Default  1629.000000    distribution  1629.000000  19.0000  19.0000
# 2690   Default   852.000000          island   852.000000  18.0000  18.0000
# 7304   Default  1031.000000            taxa  1031.000000  17.0000  17.0000
# 9655   Default  2217.000000            area  2217.000000  16.0000  16.0000
# 19369  Default  1560.000000          region  1560.000000  15.0000  15.0000
# 7277   Default  2767.000000          number  2767.000000  14.0000  14.0000
# 12726  Default  3750.000000    biodiversity  3750.000000  13.0000  13.0000
# 17406  Default   617.000000          native   617.000000  12.0000  12.0000
# 4478   Default  3193.000000            site  3193.000000  11.0000  11.0000
# 16005  Default  1527.000000          change  1527.000000  10.0000  10.0000
# 15883  Default   828.000000            rare   828.000000   9.0000   9.0000
# 16004  Default   841.000000         genetic   841.000000   8.0000   8.0000
# 648    Default  1158.000000           model  1158.000000   7.0000   7.0000
# 18430  Default   761.000000            seed   761.000000   6.0000   6.0000
# 20172  Default  1475.000000           total  1475.000000   5.0000   5.0000
# 2972   Default   831.000000            plot   831.000000   4.0000   4.0000
# 17544  Default  1638.000000          sample  1638.000000   3.0000   3.0000
# 4869   Default  1155.000000           range  1155.000000   2.0000   2.0000
# 6121   Default  1459.000000         pattern  1459.000000   1.0000   1.0000
# ...        ...          ...             ...          ...      ...      ...
# 5699   Topic12    69.405220   concentration    70.590538   5.0756  -3.7949
# 17607  Topic12    57.891911    semi_natural    59.077209   5.0723  -3.9763
# 13944  Topic12    45.515293        adoption    46.700695   5.0669  -4.2168
# 16415  Topic12    40.166451     competition    41.351749   5.0635  -4.3419
# 11234  Topic12    37.235420           sheep    38.420746   5.0612  -4.4176
# 18273  Topic12    35.814816      pollinator    37.000103   5.0600  -4.4565
# 9247   Topic12    35.456909             bee    36.642227   5.0597  -4.4666
# 21714  Topic12    31.337463     pollination    32.522755   5.0555  -4.5901
# 5935   Topic12    29.019400        constant    30.204737   5.0525  -4.6669
# 927    Topic12    27.772173     predominant    28.957518   5.0508  -4.7109
# 4542   Topic12    22.861277       technical    24.046589   5.0420  -4.9054
# 17202  Topic12    21.893812          floral    23.079111   5.0399  -4.9487
# 12529  Topic12    16.375957  methodological    17.561260   5.0227  -5.2391
# 13761  Topic12    16.270903       pollinate    17.456215   5.0223  -5.2455
# 7584   Topic12    14.378037     hymenoptera    15.563348   5.0134  -5.3692
# 10118  Topic12    14.108826          greece    15.294121   5.0119  -5.3881
# 22277  Topic12    14.048531           error    15.233821   5.0116  -5.3924
# 12508  Topic12    13.074234            sell    14.259541   5.0058  -5.4642
# 9422   Topic12    12.972056              fd    14.157461   5.0051  -5.4721
# 19093  Topic12    12.437304            load    13.622599   5.0016  -5.5142
# 17292  Topic12    10.880110      visitation    12.065401   4.9892  -5.6480
# 20438  Topic12     9.782307        honeybee    10.967595   4.9782  -5.7543
# 10254  Topic12     6.834234      phosphorus     8.019540   4.9326  -6.1129
# 15717  Topic12     6.203062         version     7.388359   4.9177  -6.2098
# 16672  Topic12     5.653595      competitor     6.838904   4.9022  -6.3026
# 23451  Topic12     4.627139        internet     5.812431   4.8645  -6.5029
# 4336   Topic12    40.050938     fluctuation    74.648270   4.4699  -4.3447
# 5365   Topic12    41.128056           trait   114.472183   4.0689  -4.3182
# 8739   Topic12    38.856705    reproductive   107.068443   4.0790  -4.3750
# 928    Topic12     7.373934            hand   136.367661   2.1752  -6.0369
#
# [576 rows x 6 columns], token_table=       Topic      Freq           Term
# term
# 23739      8  0.982472         absent
# 5874       1  0.972637      abundance
# 5874       5  0.026770      abundance
# 12303      1  0.995856       abundant
# 20906      8  0.971644         acacia
# 10623      9  0.979952      accession
# 4067       7  0.980604      accompany
# 14764      9  0.982864           acid
# 7935       2  0.995435         action
# 10031      1  0.203628       activity
# 10031      2  0.501347       activity
# 10031      5  0.292101       activity
# 1237       7  0.989595     adaptation
# 13944     12  0.984996       adoption
# 3943       7  0.983523        advance
# 8454      11  0.990440          algae
# 15846     11  0.986644          algal
# 4706       8  0.990937          alien
# 23847      4  0.992380         alpine
# 18025      4  0.546196       altitude
# 18025      6  0.446888       altitude
# 12815      4  0.991189       amazonia
# 8372       4  0.996036      amazonian
# 2268       6  0.975973     angiosperm
# 14098      1  0.104365         animal
# 14098      2  0.533686         animal
# 14098      5  0.360534         animal
# 7097       1  0.282911         annual
# 7097       3  0.111016         annual
# 7097       4  0.164733         annual
# ...      ...       ...            ...
# 17292     12  0.911698     visitation
# 8897       2  0.237372  vulnerability
# 8897       7  0.753042  vulnerability
# 18657      1  0.521232          water
# 18657      3  0.272462          water
# 18657      5  0.104641          water
# 18657      9  0.100693          water
# 14180      8  0.977025           weed
# 13583      6  0.968624    west_africa
# 21107      5  0.997500        wetland
# 13460      3  0.703118           wild
# 13460      8  0.160925           wild
# 13460      9  0.136167           wild
# 21040      2  0.276926       wildlife
# 21040      5  0.720911       wildlife
# 19662      3  0.989495         winter
# 5542       1  0.996380           wood
# 17747      1  0.998785       woodland
# 15270      6  0.689644          woody
# 15270      8  0.305414          woody
# 12987      2  0.997553          world
# 12786      1  0.272461           year
# 12786      2  0.068359           year
# 12786      3  0.063477           year
# 12786      4  0.119141           year
# 12786      5  0.477540           year
# 18764      1  0.629380           zone
# 18764      2  0.016815           zone
# 18764      4  0.103295           zone
# 18764      6  0.247428           zone
#
# [806 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'ylab': 'PC2', 'xlab': 'PC1'}, topic_order=[12, 5, 11, 9, 4, 7, 2, 10, 6, 1, 8, 3])

# %%
topics = optimal_model.show_topics(num_topics = -1, formatted=False)

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.XKCD_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab8',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

fig, axes = plt.subplots(6, 2, figsize = (20, 30), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
from collections import Counter
topics = optimal_model.show_topics(num_topics = -1, formatted=False)
data_flat = [w for w_list in textual_data_lemmatized for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(6, 2, figsize=(20, 40), sharey=True, dpi=160)
cols = [color for name, color in mcolors.XKCD_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax.set_title('Topic: ' + str(i+1), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=True)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

plt.show()
