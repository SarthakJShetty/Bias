# %% [markdown]
# ### Natural Language Processing Script

# %% [markdown]
# This script can be used as a standalone program to process and prepare topic modelling of the ```Scraper.py``` datasets generated.

# %% [markdown]
# ### 1.0 <u>Code:</u>

# %% [markdown]
# Here, we import the libraries required to run the script.

# %%
'''Natural Language toolkit. Here we download the commonly used English stopwords'''
import nltk; nltk.download('stopwords')
'''Standard set of functions for reading and appending files'''
import re
'''Pandas and numpy is a dependency used by other portions of the code.'''
import numpy as np
import pandas as pd
'''Think this stands for pretty print. Prints out stuff to the terminal in a prettier way'''
from pprint import pprint

'''Contains the language model that has to be developed.'''
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
'''Industrial level toolkit for NLP'''
import spacy

'''Importing OS here to build the directories to hold the status logger logs'''
import os

import pyLDAvis
import pyLDAvis.gensim

'''Importing datetime here to log the time when specfic functions are triggered'''
from datetime import datetime

'''Make pretty visualizations'''
import matplotlib.pyplot as plt

'''Library to log any errors. Came across this in the tutorial.'''
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'com', 'https', 'url', 'link', 'xe', 'abstract', 'author', 'chapter', 'springer', 'title', "the", "of", "and", "in", "to", "a", "is", "for", "from", "with", "that","by", "are", "on", "was", "as", "were", "url:", "abstract:", "abstract",  "author:", "title:", "at", "be", "an", "during", "have", "this", "which", "study", "been", "species", "not", "has", "between", "using", "its", "also", "these", "this", "used", "over", "can", "within", "into", "all","due", "use", "about", "a", 'it', 'their', "where", "we", "most", "may", "through", "though", "like", "or", "further", "e.g.", "along", "any", "those", "had", "toward", "due", "both", "some", "use", "even", "more", "but", "while", "pass", "well", "will", "when", "only", "after", "author", "title", "there", "our", "did", "much", "as", "if", "become", "still", "various", "very", "out", "they", "via", "available", "such", "than", "different", "many", "areas", "no", "one", "two", "small", "first", "other", "such", "-", "could", "studies", "high","provide", "among", "highly", "no", "case", "across", "given", "need", "would", "under", "found", "low", "values", "xe2\\x80\\x89"])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sarthak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Defining the abstracts log name that will be processed by the rest of the script. The status logger function of the main script has been imported here, and the name of the ```.txt``` file used to log the information has to be added here.

# %%
abstracts_log_name = "/home/sarthak/projects/Bias/BackUp_Journal_LOGS/Test_Bed_Master_Copy/CompletelyCleanCorpus_12_Topics"
session_folder_name = abstracts_log_name.split('/')[7]
os.makedirs(session_folder_name)
status_logger_name = session_folder_name+"/"+"Status_Logger"+"_"+abstracts_log_name.split('/')[7]

# %% [markdown]
# This function is responsible for generating a ```.txt``` file for analysis once the code has run. This code has been copied directly from the ```common_functions.py``` script of the main code.

# %%
def status_logger(status_logger_name, status_key):
	'''Status logger to print and log details throught the running the program.
	Declaring current_hour, current_minute & current_second.'''
	current_hour = str(datetime.now().time().hour)
	current_minute = str(datetime.now().time().minute)
	current_second = str(datetime.now().time().second)
	'''Logging the complete_status_key and printing the complete_status_key'''
	complete_status_key = "[INFO]"+current_hour+":"+current_minute+":"+current_second+" "+status_key
	print(complete_status_key)
	status_log = open(status_logger_name+'.txt', 'a')
	status_log.write(complete_status_key+"\n")
	status_log.close()

# %% [markdown]
# Here, we read the ```.txt``` file generated from the journal scrapping, that has to be profiled using topic models.

# %%
def data_reader(abstracts_log_name, status_logger_name):
	data_reader_start_status_key = abstracts_log_name+".txt is being ported to dataframe"
	status_logger(status_logger_name, data_reader_start_status_key)
	textual_dataframe = pd.read_csv(abstracts_log_name+'.txt', delimiter="\t")
	data_reader_end_status_key = abstracts_log_name+".txt has been ported to dataframe"	
	status_logger(status_logger_name, data_reader_end_status_key)
	return textual_dataframe

# %% [markdown]
# Taking the abstracts and preparing a list of abstracts.

# %%
def textual_data_trimmer(textual_dataframe, status_logger_name):
	textual_data_trimmer_start_status_key = "Trimming data and preparing list of words"
	status_logger(status_logger_name, textual_data_trimmer_start_status_key)

	'''This function converts the textual data into a list and removes special characters, virtue of email correspondence'''
	textual_data = textual_dataframe.values.tolist()
	print(textual_data)

	textual_data_trimmer_end_status_key = "Trimmed data and prepared list of words"
	status_logger(status_logger_name, textual_data_trimmer_end_status_key)
	return textual_data

# %% [markdown]
# Tokenizing the words here and also removing punctuations from the corpus.

# %%
def sent_to_words(textual_data, status_logger_name):
	sent_to_words_start_status_key = "Tokenizing words"
	status_logger(status_logger_name, sent_to_words_start_status_key)
	'''This function tokenizes each sentence into individual words; also called tokens'''
	for sentence in textual_data:
		yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
	textual_data = list(sent_to_words(textual_data))
	sent_to_words_end_status_key = "Tokenized words"
	status_logger(status_logger_name, sent_to_words_end_status_key)	
	return textual_data

# %% [markdown]
# Generating ***```bigrams```*** from the ```textual_data``` that we have prepared from the abstracts. **Bigrams** are words that occur together, multiple times in a given body of text. For example, *torrential* and *rain* occur together more often with each other, as opposed to other adjective-noun pairs. Hence the two would form a bigram here.

# %%
def bigram_generator(textual_data, status_logger_name):
	bigram_generator_start_status_key = "Generating word bigrams"
	status_logger(status_logger_name, bigram_generator_start_status_key)	
	'''Takes the textual data and prepares the bigram, two collectively high frequency words'''
	bigram = gensim.models.Phrases(textual_data, min_count=5, threshold=100)
	bigram_mod = gensim.models.phrases.Phraser(bigram)
	bigram_generator_end_status_key = "Generated word bigrams"
	status_logger(status_logger_name, bigram_generator_end_status_key)	
	return bigram_mod

# %% [markdown]
# Here, we use the ```bigram_mod``` model to generate bigrams from our ```corpus```.

# %%
def make_bigrams(textual_data, status_logger_name):
	'''Generates multiple bigrams of word pairs in phrases that commonly occuring with each other over the corpus'''
	make_bigrams_start_status_key = "Generating bigrams"
	status_logger(status_logger_name, make_bigrams_start_status_key)

	bigram_mod = bigram_generator(textual_data, status_logger_name)
	return [bigram_mod[doc] for doc in textual_data]

	make_bigrams_end_status_key = "Generated bigrams"

# %% [markdown]
# We remove the stopwords, as specified in a list at the start of the program. There's a marked improvement in the topics and keywords produced after expanding the cache of the words to be filtered out.

# %%
def remove_stopwords(textual_data, status_logger_name):
	'''This function removes the standard set of stopwords from the corpus of abstract words'''
	remove_stopwords_start_status_key = "Removing stopwords"
	status_logger(status_logger_name, remove_stopwords_start_status_key)
	return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in textual_data]
	remove_stopwords_end_status_key = "Removed stopwords"
	status_logger(status_logger_name, remove_stopwords_end_status_key)

# %% [markdown]
# Generating the ```pyLDAvis``` visualization from the ```lda_model``` generated and trained on our ```corpus``` & ```id2word``` dictionary. The time taken here is proportional to the size of the ```corpus```.

# %%
def visualizer_generator(lda_model, corpus, id2word, logs_folder_name, status_logger_name):
	'''This code generates the .html file with generates the visualization of the data prepared.'''
	visualizer_generator_start_status_key = "Preparing the topic modeling visualization"
	status_logger(status_logger_name, visualizer_generator_start_status_key)
    
	textual_data_visualization = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
	pyLDAvis.save_html(textual_data_visualization, session_folder_name+'/'+"Data_Visualization_Topic_Modelling.html")

	visualizer_generator_end_status_key = "Prepared the topic modeling visualization"+" "+"Data_Visualization_Topic_Modelling.html"
	status_logger(status_logger_name, visualizer_generator_end_status_key)

# %% [markdown]
# Lemmatization involves truncating a term to its root term. For example *running -> run* is an example of the ```lemmatization``` process.

# %%
def lemmatization(status_logger_name, textual_data, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
	lemmatization_start_status_key = "Beginning lemmatization"
	status_logger(status_logger_name, lemmatization_start_status_key)
	"""https://spacy.io/api/annotation"""
	texts_out = []
	nlp = spacy.load('en', disable=['parser', 'ner'])
	for sent in textual_data:
		doc = nlp(" ".join(sent))
		texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
	lemmatization_end_status_key = "Ending lemmatization"
	status_logger(status_logger_name, lemmatization_end_status_key)
	return texts_out

# %% [markdown]
# Calling the ```nlp_engine_main()``` function where all the previously defined functions come together and generate the ```pyLDAvis``` visualization for topic analysis.

# %%
nlp_engine_main_start_status_key = "Initiating the NLP Engine"
status_logger(status_logger_name, nlp_engine_main_start_status_key)

'''Extracts the data from the .txt file and puts them into a Pandas dataframe buckets'''
textual_dataframe = data_reader(abstracts_log_name, status_logger_name)
'''Rids the symbols and special characters from the textual_data'''
textual_data = textual_data_trimmer(textual_dataframe, status_logger_name)
'''Removes stopwords that were earlier downloaded from the textual_data'''
textual_data_no_stops = remove_stopwords(textual_data, status_logger_name)
'''Prepares bigrams'''
textual_data_words_bigrams = make_bigrams(textual_data_no_stops, status_logger_name)
'''Loads the English model from spaCy'''
nlp = spacy.load('en', disable=['parser', 'ner'])

textual_data_lemmatized = lemmatization(status_logger_name, textual_data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

id2word = corpora.Dictionary(textual_data_lemmatized)

texts = textual_data_lemmatized
corpus = [id2word.doc2bow(text) for text in texts]

[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]

'''Builds the actual LDA model that will be used for the visualization and inference'''
lda_model = gensim.models.ldamodel.LdaModel(corpus = corpus, id2word = id2word, num_topics = 12, random_state = 100, update_every = 1, chunksize = 100, passes = 10, alpha = 'symmetric', per_word_topics = True)

doc_lda = lda_model[corpus]

perplexity_score = lda_model.log_perplexity(corpus)

perplexity_status_key = "Issued perplexity:"+" "+str(perplexity_score)

status_logger(status_logger_name, perplexity_status_key)

nlp_engine_main_end_status_key = "Idling the NLP Engine"
status_logger(status_logger_name, nlp_engine_main_end_status_key)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [INFO]11:22:49 Generating bigrams
# [INFO]11:22:49 Generating word bigrams
# [INFO]11:22:54 Generated word bigrams
# [INFO]11:22:56 Beginning lemmatization
# [INFO]11:23:19 Ending lemmatization
# [INFO]11:23:55 Issued perplexity: -9.42808103444275
# [INFO]11:23:55 Idling the NLP Engine

# %%
lda_model

# %% [markdown]
# Presenting the topics of the trained ```LDA``` model here.

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.070*"mammal" + 0.041*"urban" + 0.033*"standard" + 0.031*"extinct" + 0.022*"gene" + 0.019*"peninsula" + 0.018*"phylogenetic" + 0.018*"difficulty" + 0.017*"taxonomy" + 0.016*"carnivore"'),
#  (1,
#   '0.033*"hunt" + 0.031*"people" + 0.019*"systematic" + 0.017*"climate_change" + 0.017*"climate" + 0.016*"valley" + 0.015*"climatic" + 0.013*"description" + 0.013*"arise" + 0.013*"inadequate"'),
#  (2,
#   '0.053*"nutrient" + 0.044*"social" + 0.037*"flower" + 0.035*"pollen" + 0.022*"concentration" + 0.019*"semi_natural" + 0.015*"adoption" + 0.013*"trait" + 0.013*"competition" + 0.013*"fluctuation"'),
#  (3,
#   '0.040*"bird" + 0.024*"population" + 0.016*"year" + 0.016*"wildlife" + 0.016*"decline" + 0.013*"km" + 0.011*"wetland" + 0.011*"nest" + 0.010*"fire" + 0.010*"animal"'),
#  (4,
#   '0.030*"conservation" + 0.020*"biodiversity" + 0.009*"protect" + 0.008*"management" + 0.007*"resource" + 0.007*"base" + 0.007*"datum" + 0.006*"reserve" + 0.006*"information" + 0.006*"development"'),
#  (5,
#   '0.068*"soil" + 0.025*"microbial" + 0.023*"bacteria" + 0.022*"strain" + 0.021*"microorganism" + 0.016*"protozoa" + 0.015*"productivity" + 0.015*"pest" + 0.013*"edible" + 0.013*"disease"'),
#  (6,
#   '0.074*"endemic" + 0.063*"plant" + 0.059*"island" + 0.031*"butterfly" + 0.030*"taxa" + 0.027*"rare" + 0.026*"distribution" + 0.025*"flora" + 0.022*"region" + 0.017*"richness"'),
#  (7,
#   '0.036*"algae" + 0.029*"algal" + 0.028*"colonization" + 0.028*"bryophyte" + 0.025*"damage" + 0.024*"sediment" + 0.020*"frequent" + 0.019*"root" + 0.018*"overview" + 0.016*"benthic"'),
#  (8,
#   '0.190*"forest" + 0.055*"tree" + 0.017*"plot" + 0.015*"tropical" + 0.010*"primary" + 0.010*"density" + 0.009*"log" + 0.009*"fungi" + 0.008*"lichen" + 0.008*"secondary"'),
#  (9,
#   '0.075*"native" + 0.043*"plantation" + 0.041*"plant" + 0.031*"cultivate" + 0.025*"exotic" + 0.021*"invasion" + 0.019*"alien" + 0.016*"perennial" + 0.016*"crop" + 0.015*"seed_bank"'),
#  (10,
#   '0.051*"population" + 0.020*"genetic" + 0.019*"model" + 0.016*"estimate" + 0.016*"distribution" + 0.015*"seed" + 0.013*"number" + 0.012*"extinction" + 0.011*"river" + 0.010*"range"'),
#  (11,
#   '0.024*"diversity" + 0.024*"habitat" + 0.017*"site" + 0.014*"richness" + 0.013*"community" + 0.011*"plant" + 0.010*"number" + 0.009*"vegetation" + 0.007*"type" + 0.007*"increase"')]

# %% [markdown]
# Declaring the ```mallet``` path here. Part of the GitHub package that you've cloned.

# %%
mallet_path = '/home/sarthak/projects/Bias/mallet-2.0.8/bin/mallet'

# %% [markdown]
# Building the ```LDA mallet``` model here, to generate the representative documents, run the coherence tests and issue perplexity here.

# %%
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=12, id2word=id2word)

# %% [markdown]
# Just checking out the topics of the ```LDA mallet``` model here.

# %%
pprint(ldamallet.show_topics(formatted=False))
# Out:
# [(3,
#   [('datum', 0.04124329047559606),
#    ('model', 0.03649981275745849),
#    ('base', 0.023867182623892147),
#    ('method', 0.021844963175633503),
#    ('estimate', 0.017850455623517662),
#    ('survey', 0.01702658844089377),
#    ('result', 0.016926725752090876),
#    ('information', 0.01440519285981775),
#    ('analysis', 0.01290725252777431),
#    ('identify', 0.01041068530770191)]),
#  (7,
#   [('forest', 0.15758660731565705),
#    ('tree', 0.05029514224888717),
#    ('stand', 0.014345848654925488),
#    ('tropical', 0.012676601509580027),
#    ('disturbance', 0.012555641571511515),
#    ('density', 0.012410489645829302),
#    ('plantation', 0.012337913682988194),
#    ('composition', 0.011636346042190826),
#    ('plot', 0.010499322624346816),
#    ('site', 0.008684923553319141)]),
#  (8,
#   [('habitat', 0.10770106491473568),
#    ('landscape', 0.0402959941180656),
#    ('scale', 0.02134572966819249),
#    ('effect', 0.021203424803737873),
#    ('factor', 0.01954320138510068),
#    ('patch', 0.014183051490643455),
#    ('variable', 0.013424092213552166),
#    ('influence', 0.01328178734909755),
#    ('structure', 0.012024761046415103),
#    ('increase', 0.01157412897564215)]),
#  (1,
#   [('conservation', 0.10020760544837713),
#    ('protect', 0.0337485442300876),
#    ('threaten', 0.023267000860803078),
#    ('biodiversity', 0.021722618866778065),
#    ('reserve', 0.018330042027444426),
#    ('include', 0.01572231505392678),
#    ('threat', 0.015317231252215301),
#    ('priority', 0.013519671882120613),
#    ('protection', 0.013291812243657906),
#    ('area', 0.01326649450605094)]),
#  (0,
#   [('vegetation', 0.03616175783076204),
#    ('plant', 0.034361851332398316),
#    ('site', 0.03162692847124825),
#    ('richness', 0.026554464703132306),
#    ('community', 0.025525946704067323),
#    ('grassland', 0.020827489481065917),
#    ('composition', 0.016993922393641888),
#    ('abundance', 0.0146096306685367),
#    ('diversity', 0.013955119214586255),
#    ('management', 0.013651238896680691)]),
#  (6,
#   [('population', 0.06756300776079113),
#    ('native', 0.024424429620785424),
#    ('plant', 0.021673112362758585),
#    ('decline', 0.021257819191735666),
#    ('island', 0.019985983855477975),
#    ('impact', 0.013497028058244867),
#    ('extinction', 0.012406883484309706),
#    ('seed', 0.011991590313286785),
#    ('increase', 0.011757987904586395),
#    ('rate', 0.01149842967269707)]),
#  (9,
#   [('distribution', 0.046849098467266835),
#    ('region', 0.03942771161153758),
#    ('endemic', 0.022952742852770908),
#    ('range', 0.021269541710234374),
#    ('area', 0.020096401519981637),
#    ('plant', 0.01958634056769784),
#    ('record', 0.01721455713957818),
#    ('rare', 0.01433271275917472),
#    ('climate_change', 0.01198643237866925),
#    ('hotspot', 0.010354237331361097)]),
#  (2,
#   [('bird', 0.03722361398540464),
#    ('large', 0.020340921468249645),
#    ('site', 0.017018843263261082),
#    ('number', 0.01669208147260647),
#    ('abundance', 0.014159677595033221),
#    ('density', 0.013370003267617907),
#    ('mammal', 0.01331554296917547),
#    ('individual', 0.012716479686308681),
#    ('nest', 0.009775623570417166),
#    ('bat', 0.008332425661692625)]),
#  (5,
#   [('local', 0.022694613745602298),
#    ('management', 0.021629255240077302),
#    ('resource', 0.021059412318517417),
#    ('human', 0.013131162975075565),
#    ('wildlife', 0.011892374015162776),
#    ('conservation', 0.010926118626430802),
#    ('activity', 0.010133293692086615),
#    ('development', 0.010009414796095337),
#    ('natural', 0.009538674991328478),
#    ('wild', 0.009191814082552896)]),
#  (11,
#   [('biodiversity', 0.05270170924462415),
#    ('conservation', 0.02338724499172946),
#    ('research', 0.016403234699503767),
#    ('ecological', 0.015851865465907004),
#    ('management', 0.014863995589046131),
#    ('process', 0.013347730196655026),
#    ('knowledge', 0.013186914170189303),
#    ('approach', 0.011303069288733689),
#    ('ecosystem', 0.009166513508546224),
#    ('paper', 0.009143539790479691)])]

# %% [markdown]
# Presenting the "Coherence" of the model here. Coherence is a proxy for how well the model has been built and trained.

# %%
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=textual_data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# Coherence Score:  0.46421359254666

# %% [markdown]
# Presenting the coherence here for a bunch of trained models. Will be eventually selecting the ```optimal_model``` as the ```lda_model```, to get the representative documents with corresponding ```num_topics```.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# %% [markdown]
# Computing coherence from the previously generated ```mallet``` models, to find the model with the best coherence, and thereby the best model.

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=textual_data_lemmatized, start=2, limit=40, step=6)

# %% [markdown]
# Plotting the computed coherence scores here for the models that we generated.

# %%
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# Declaring the ```optimal_model``` as the previously generated ```ldamallet``` model.

# %%
optimal_model = ldamallet

# %% [markdown]
# Presenting the topics of the ```ldamallet``` model here.

# %%
model_topics = optimal_model.show_topics(formatted=False)
print(model_topics)
# Out:
# [(9, [('distribution', 0.046849098467266835), ('region', 0.03942771161153758), ('endemic', 0.022952742852770908), ('range', 0.021269541710234374), ('area', 0.020096401519981637), ('plant', 0.01958634056769784), ('record', 0.01721455713957818), ('rare', 0.01433271275917472), ('climate_change', 0.01198643237866925), ('hotspot', 0.010354237331361097)]), (6, [('population', 0.06756300776079113), ('native', 0.024424429620785424), ('plant', 0.021673112362758585), ('decline', 0.021257819191735666), ('island', 0.019985983855477975), ('impact', 0.013497028058244867), ('extinction', 0.012406883484309706), ('seed', 0.011991590313286785), ('increase', 0.011757987904586395), ('rate', 0.01149842967269707)]), (7, [('forest', 0.15758660731565705), ('tree', 0.05029514224888717), ('stand', 0.014345848654925488), ('tropical', 0.012676601509580027), ('disturbance', 0.012555641571511515), ('density', 0.012410489645829302), ('plantation', 0.012337913682988194), ('composition', 0.011636346042190826), ('plot', 0.010499322624346816), ('site', 0.008684923553319141)]), (1, [('conservation', 0.10020760544837713), ('protect', 0.0337485442300876), ('threaten', 0.023267000860803078), ('biodiversity', 0.021722618866778065), ('reserve', 0.018330042027444426), ('include', 0.01572231505392678), ('threat', 0.015317231252215301), ('priority', 0.013519671882120613), ('protection', 0.013291812243657906), ('area', 0.01326649450605094)]), (4, [('community', 0.021747040219429595), ('ecosystem', 0.018472389375577263), ('soil', 0.01749279296929665), ('water', 0.014581992219205687), ('change', 0.011755156875367349), ('impact', 0.01164320300036385), ('river', 0.011055445156595482), ('assemblage', 0.010215791094069244), ('wetland', 0.01018780262531837), ('fish', 0.009544067844048251)]), (11, [('biodiversity', 0.05270170924462415), ('conservation', 0.02338724499172946), ('research', 0.016403234699503767), ('ecological', 0.015851865465907004), ('management', 0.014863995589046131), ('process', 0.013347730196655026), ('knowledge', 0.013186914170189303), ('approach', 0.011303069288733689), ('ecosystem', 0.009166513508546224), ('paper', 0.009143539790479691)]), (10, [('diversity', 0.08186058564394921), ('richness', 0.04648872764965017), ('group', 0.029955947136563875), ('pattern', 0.02225965275978233), ('genetic', 0.020963980305778698), ('number', 0.019823788546255508), ('level', 0.01764705882352941), ('taxa', 0.017543405027209122), ('variation', 0.0167141746566468), ('sample', 0.0153925887535631)]), (2, [('bird', 0.03722361398540464), ('large', 0.020340921468249645), ('site', 0.017018843263261082), ('number', 0.01669208147260647), ('abundance', 0.014159677595033221), ('density', 0.013370003267617907), ('mammal', 0.01331554296917547), ('individual', 0.012716479686308681), ('nest', 0.009775623570417166), ('bat', 0.008332425661692625)]), (3, [('datum', 0.04124329047559606), ('model', 0.03649981275745849), ('base', 0.023867182623892147), ('method', 0.021844963175633503), ('estimate', 0.017850455623517662), ('survey', 0.01702658844089377), ('result', 0.016926725752090876), ('information', 0.01440519285981775), ('analysis', 0.01290725252777431), ('identify', 0.01041068530770191)]), (8, [('habitat', 0.10770106491473568), ('landscape', 0.0402959941180656), ('scale', 0.02134572966819249), ('effect', 0.021203424803737873), ('factor', 0.01954320138510068), ('patch', 0.014183051490643455), ('variable', 0.013424092213552166), ('influence', 0.01328178734909755), ('structure', 0.012024761046415103), ('increase', 0.01157412897564215)])]

# %% [markdown]
# ```num_words``` dictates the number of keywords to be presented with each topic.

# %%
pprint(optimal_model.print_topics(num_words=40))
# Out:
# [(0,
#   '0.036*"vegetation" + 0.034*"plant" + 0.032*"site" + 0.027*"richness" + '
#   '0.026*"community" + 0.021*"grassland" + 0.017*"composition" + '
#   '0.015*"abundance" + 0.014*"diversity" + 0.014*"management" + 0.013*"land" + '
#   '0.012*"cover" + 0.011*"significantly" + 0.011*"effect" + 0.011*"type" + '
#   '0.011*"ant" + 0.011*"butterfly" + 0.011*"assemblage" + 0.010*"woodland" + '
#   '0.010*"insect" + 0.009*"high" + 0.009*"increase" + 0.009*"restoration" + '
#   '0.007*"pasture" + 0.007*"compare" + 0.006*"open" + 0.006*"shrub" + '
#   '0.006*"beetle" + 0.006*"arthropod" + 0.006*"plot" + 0.006*"difference" + '
#   '0.005*"change" + 0.005*"significant" + 0.005*"structure" + 0.005*"result" + '
#   '0.005*"burn" + 0.005*"ground" + 0.005*"spider" + 0.005*"graze" + '
#   '0.005*"affect"'),
#  (1,
#   '0.100*"conservation" + 0.034*"protect" + 0.023*"threaten" + '
#   '0.022*"biodiversity" + 0.018*"reserve" + 0.016*"include" + 0.015*"threat" + '
#   '0.014*"priority" + 0.013*"protection" + 0.013*"area" + 0.013*"identify" + '
#   '0.013*"status" + 0.012*"strategy" + 0.011*"target" + 0.010*"list" + '
#   '0.010*"level" + 0.010*"network" + 0.009*"endanger" + 0.009*"exist" + '
#   '0.009*"base" + 0.008*"criterion" + 0.008*"assessment" + 0.008*"plan" + '
#   '0.008*"effective" + 0.007*"represent" + 0.007*"assess" + 0.007*"effort" + '
#   '0.007*"conserve" + 0.007*"system" + 0.007*"planning" + 0.007*"important" + '
#   '0.007*"risk" + 0.006*"global" + 0.006*"national" + 0.006*"action" + '
#   '0.006*"select" + 0.006*"propose" + 0.005*"regional" + 0.005*"category" + '
#   '0.005*"measure"'),
#  (2,
#   '0.037*"bird" + 0.020*"large" + 0.017*"site" + 0.017*"number" + '
#   '0.014*"abundance" + 0.013*"density" + 0.013*"mammal" + 0.013*"individual" + '
#   '0.010*"nest" + 0.008*"bat" + 0.008*"survey" + 0.008*"period" + '
#   '0.008*"common" + 0.008*"area" + 0.008*"animal" + 0.008*"road" + '
#   '0.007*"increase" + 0.007*"suggest" + 0.007*"high" + 0.007*"range" + '
#   '0.007*"season" + 0.007*"year" + 0.007*"capture" + 0.006*"size" + '
#   '0.006*"human" + 0.006*"breeding" + 0.006*"relative" + 0.005*"great" + '
#   '0.005*"predator" + 0.005*"record" + 0.005*"trap" + 0.005*"carnivore" + '
#   '0.005*"breed" + 0.005*"activity" + 0.004*"prey" + 0.004*"forage" + '
#   '0.004*"compare" + 0.004*"mortality" + 0.004*"winter" + 0.004*"study"'),
#  (3,
#   '0.041*"datum" + 0.036*"model" + 0.024*"base" + 0.022*"method" + '
#   '0.018*"estimate" + 0.017*"survey" + 0.017*"result" + 0.014*"information" + '
#   '0.013*"analysis" + 0.010*"identify" + 0.010*"sample" + 0.010*"predict" + '
#   '0.009*"spatial" + 0.009*"indicator" + 0.009*"collection" + '
#   '0.009*"monitoring" + 0.008*"field" + 0.008*"assess" + 0.008*"good" + '
#   '0.008*"monitor" + 0.008*"map" + 0.007*"technique" + 0.007*"set" + '
#   '0.007*"approach" + 0.007*"apply" + 0.007*"obtain" + 0.007*"scale" + '
#   '0.006*"collect" + 0.006*"potential" + 0.006*"evaluate" + 0.006*"develop" + '
#   '0.006*"assessment" + 0.005*"compare" + 0.005*"test" + 0.005*"data" + '
#   '0.005*"inventory" + 0.005*"variable" + 0.005*"make" + 0.005*"combine" + '
#   '0.005*"select"'),
#  (4,
#   '0.022*"community" + 0.018*"ecosystem" + 0.017*"soil" + 0.015*"water" + '
#   '0.012*"change" + 0.012*"impact" + 0.011*"river" + 0.010*"assemblage" + '
#   '0.010*"wetland" + 0.010*"fish" + 0.010*"environment" + 0.009*"level" + '
#   '0.009*"marine" + 0.008*"coastal" + 0.008*"invertebrate" + 0.007*"important" '
#   '+ 0.007*"aquatic" + 0.006*"riparian" + 0.006*"major" + 0.006*"fauna" + '
#   '0.006*"stream" + 0.006*"condition" + 0.006*"pond" + 0.006*"include" + '
#   '0.005*"terrestrial" + 0.005*"environmental" + 0.005*"diverse" + '
#   '0.005*"freshwater" + 0.005*"show" + 0.005*"biomass" + 0.005*"organism" + '
#   '0.005*"lake" + 0.005*"zone" + 0.005*"surface" + 0.004*"site" + '
#   '0.004*"occur" + 0.004*"increase" + 0.004*"associate" + 0.004*"role" + '
#   '0.004*"system"'),
#  (5,
#   '0.023*"local" + 0.022*"management" + 0.021*"resource" + 0.013*"human" + '
#   '0.012*"wildlife" + 0.011*"conservation" + 0.010*"activity" + '
#   '0.010*"development" + 0.010*"natural" + 0.009*"practice" + 0.009*"wild" + '
#   '0.009*"benefit" + 0.009*"land" + 0.008*"economic" + 0.008*"country" + '
#   '0.008*"people" + 0.008*"traditional" + 0.007*"community" + 0.007*"crop" + '
#   '0.007*"system" + 0.007*"farm" + 0.006*"sustainable" + 0.006*"conflict" + '
#   '0.006*"support" + 0.006*"production" + 0.006*"park" + 0.006*"harvest" + '
#   '0.006*"state" + 0.005*"indigenous" + 0.005*"palm" + 0.005*"trade" + '
#   '0.005*"programme" + 0.005*"pressure" + 0.004*"animal" + 0.004*"develop" + '
#   '0.004*"potential" + 0.004*"farmer" + 0.004*"cost" + 0.004*"agriculture" + '
#   '0.004*"livestock"'),
#  (6,
#   '0.068*"population" + 0.024*"native" + 0.022*"plant" + 0.021*"decline" + '
#   '0.020*"island" + 0.013*"impact" + 0.012*"extinction" + 0.012*"seed" + '
#   '0.012*"increase" + 0.011*"rate" + 0.011*"change" + 0.010*"fire" + '
#   '0.010*"reduce" + 0.009*"loss" + 0.009*"time" + 0.008*"dispersal" + '
#   '0.008*"invasive" + 0.008*"suggest" + 0.008*"effect" + 0.007*"control" + '
#   '0.007*"year" + 0.007*"recent" + 0.007*"survival" + 0.007*"introduce" + '
#   '0.006*"alien" + 0.006*"result" + 0.006*"invasion" + 0.006*"long_term" + '
#   '0.006*"growth" + 0.006*"exotic" + 0.006*"remain" + 0.005*"potential" + '
#   '0.005*"flower" + 0.005*"evidence" + 0.005*"introduction" + '
#   '0.005*"condition" + 0.005*"dynamic" + 0.005*"recovery" + 0.005*"follow" + '
#   '0.004*"lead"'),
#  (7,
#   '0.158*"forest" + 0.050*"tree" + 0.014*"stand" + 0.013*"tropical" + '
#   '0.013*"disturbance" + 0.012*"density" + 0.012*"plantation" + '
#   '0.012*"composition" + 0.010*"plot" + 0.009*"site" + 0.008*"fragment" + '
#   '0.008*"high" + 0.008*"type" + 0.008*"primary" + 0.008*"number" + '
#   '0.007*"log" + 0.007*"structure" + 0.007*"lichen" + 0.006*"compare" + '
#   '0.006*"canopy" + 0.006*"large" + 0.006*"bryophyte" + 0.006*"secondary" + '
#   '0.006*"community" + 0.006*"natural" + 0.006*"cover" + 0.006*"total" + '
#   '0.005*"manage" + 0.005*"wood" + 0.005*"low" + 0.005*"disturb" + '
#   '0.005*"individual" + 0.005*"significantly" + 0.005*"age" + 0.004*"dominate" '
#   '+ 0.004*"mature" + 0.004*"richness" + 0.004*"study" + 0.004*"diversity" + '
#   '0.004*"class"'),
#  (8,
#   '0.108*"habitat" + 0.040*"landscape" + 0.021*"scale" + 0.021*"effect" + '
#   '0.020*"factor" + 0.014*"patch" + 0.013*"variable" + 0.013*"influence" + '
#   '0.012*"structure" + 0.012*"increase" + 0.011*"edge" + 0.010*"large" + '
#   '0.010*"important" + 0.010*"type" + 0.009*"change" + 0.009*"agricultural" + '
#   '0.009*"urban" + 0.009*"environmental" + 0.008*"trait" + '
#   '0.008*"fragmentation" + 0.008*"ecological" + 0.008*"spatial" + '
#   '0.008*"affect" + 0.008*"result" + 0.007*"abundance" + 0.007*"land" + '
#   '0.007*"importance" + 0.007*"characteristic" + 0.007*"response" + '
#   '0.007*"human" + 0.007*"occurrence" + 0.007*"associate" + 0.006*"local" + '
#   '0.006*"heterogeneity" + 0.006*"size" + 0.006*"quality" + 0.006*"presence" + '
#   '0.006*"matrix" + 0.006*"relationship" + 0.005*"relate"'),
#  (9,
#   '0.047*"distribution" + 0.039*"region" + 0.023*"endemic" + 0.021*"range" + '
#   '0.020*"area" + 0.020*"plant" + 0.017*"record" + 0.014*"rare" + '
#   '0.012*"climate_change" + 0.010*"hotspot" + 0.010*"flora" + 0.010*"southern" '
#   '+ 0.009*"climate" + 0.009*"current" + 0.008*"elevation" + 0.008*"mountain" '
#   '+ 0.008*"show" + 0.008*"climatic" + 0.008*"future" + 0.007*"northern" + '
#   '0.007*"pattern" + 0.007*"total" + 0.007*"endemism" + 0.007*"western" + '
#   '0.007*"occur" + 0.007*"high" + 0.006*"central" + 0.006*"south" + '
#   '0.006*"north" + 0.006*"eastern" + 0.006*"restrict" + 0.006*"part" + '
#   '0.006*"geographical" + 0.006*"include" + 0.006*"rich" + 0.006*"present" + '
#   '0.006*"altitude" + 0.005*"geographic" + 0.005*"locate" + 0.005*"scenario"'),
#  (10,
#   '0.082*"diversity" + 0.046*"richness" + 0.030*"group" + 0.022*"pattern" + '
#   '0.021*"genetic" + 0.020*"number" + 0.018*"level" + 0.018*"taxa" + '
#   '0.017*"variation" + 0.015*"sample" + 0.014*"index" + 0.014*"show" + '
#   '0.013*"taxonomic" + 0.010*"total" + 0.010*"analysis" + 0.010*"relationship" '
#   '+ 0.009*"significant" + 0.008*"reveal" + 0.007*"high" + 0.007*"measure" + '
#   '0.007*"difference" + 0.007*"suggest" + 0.007*"explain" + 0.006*"similarity" '
#   '+ 0.006*"correlate" + 0.006*"observe" + 0.006*"component" + 0.006*"single" '
#   '+ 0.006*"result" + 0.005*"host" + 0.005*"correlation" + 0.005*"family" + '
#   '0.005*"represent" + 0.005*"describe" + 0.005*"turnover" + 0.005*"study" + '
#   '0.005*"environmental" + 0.005*"investigate" + 0.005*"analyze" + '
#   '0.005*"individual"'),
#  (11,
#   '0.053*"biodiversity" + 0.023*"conservation" + 0.016*"research" + '
#   '0.016*"ecological" + 0.015*"management" + 0.013*"process" + '
#   '0.013*"knowledge" + 0.011*"approach" + 0.009*"ecosystem" + 0.009*"paper" + '
#   '0.009*"policy" + 0.009*"environmental" + 0.007*"review" + '
#   '0.007*"scientific" + 0.007*"nature" + 0.006*"address" + 0.006*"focus" + '
#   '0.006*"discuss" + 0.006*"issue" + 0.006*"make" + 0.006*"ecosystem_service" '
#   '+ 0.006*"strategy" + 0.006*"biological" + 0.006*"challenge" + '
#   '0.005*"global" + 0.005*"understand" + 0.005*"framework" + 0.005*"interest" '
#   '+ 0.005*"provide" + 0.005*"ecology" + 0.005*"impact" + 0.005*"develop" + '
#   '0.005*"project" + 0.005*"regard" + 0.005*"highlight" + 0.004*"work" + '
#   '0.004*"support" + 0.004*"term" + 0.004*"problem" + 0.004*"environment"')]

# %% [markdown]
# This function computes the dominant topic in each sentence. We use this meta-data as a part of our framework to understand under which areas of research do the publications fall in, and also to label each of the ```pyLDAvis``` topics.

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=textual_data):
    sent_topics_df = pd.DataFrame()
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %% [markdown]
# Generating the ```dataframes``` here which contains the dominant topics for each abstract.

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=textual_data)
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0             4.0              0.3167
# 1               1             9.0              0.3063
# 2               2             9.0              0.3969
# 3               3             3.0              0.3494
# 4               4             9.0              0.2964
# 5               5             9.0              0.1638
# 6               6             9.0              0.3987
# 7               7             6.0              0.3527
# 8               8             9.0              0.4274
# 9               9             9.0              0.2391
# 10             10             3.0              0.1961
# 11             11            11.0              0.3493
# 12             12             9.0              0.3574
# 13             13             3.0              0.4138
# 14             14             9.0              0.3882
# 15             15             9.0              0.2030
# 16             16             4.0              0.1898
# 17             17             9.0              0.3662
# 18             18             9.0              0.3796
# 19             19             9.0              0.4177
# 20             20             4.0              0.3174
# 21             21             9.0              0.3073
# 22             22             9.0              0.4096
# 23             23             3.0              0.3483
# 24             24             9.0              0.3032
# 25             25             9.0              0.1728
# 26             26             9.0              0.4167
# 27             27             6.0              0.3521
# 28             28             9.0              0.4217
# 29             29             9.0              0.2446
# ...           ...             ...                 ...
# 4703         4703             6.0              0.2419
# 4704         4704             7.0              0.1469
# 4705         4705             0.0              0.0833
# 4706         4706             0.0              0.0833
# 4707         4707            11.0              0.2609
# 4708         4708            11.0              0.2177
# 4709         4709             0.0              0.0833
# 4710         4710             0.0              0.0833
# 4711         4711            10.0              0.2208
# 4712         4712            11.0              0.1963
# 4713         4713             4.0              0.2032
# 4714         4714            10.0              0.1727
# 4715         4715             4.0              0.2635
# 4716         4716            11.0              0.1636
# 4717         4717             4.0              0.2254
# 4718         4718            11.0              0.3073
# 4719         4719            10.0              0.2684
# 4720         4720             0.0              0.0833
# 4721         4721             0.0              0.0833
# 4722         4722             0.0              0.0833
# 4723         4723             4.0              0.1999
# 4724         4724            11.0              0.1625
# 4725         4725             9.0              0.1930
# 4726         4726             5.0              0.4133
# 4727         4727             6.0              0.2622
# 4728         4728             0.0              0.0833
# 4729         4729             4.0              0.2322
# 4730         4730             6.0              0.2384
# 4731         4731             9.0              0.1942
# 4732         4732            11.0              0.2490
#
#                                                Keywords  \
# 0     community, ecosystem, soil, water, change, imp...
# 1     distribution, region, endemic, range, area, pl...
# 2     distribution, region, endemic, range, area, pl...
# 3     datum, model, base, method, estimate, survey, ...
# 4     distribution, region, endemic, range, area, pl...
# 5     distribution, region, endemic, range, area, pl...
# 6     distribution, region, endemic, range, area, pl...
# 7     population, native, plant, decline, island, im...
# 8     distribution, region, endemic, range, area, pl...
# 9     distribution, region, endemic, range, area, pl...
# 10    datum, model, base, method, estimate, survey, ...
# 11    biodiversity, conservation, research, ecologic...
# 12    distribution, region, endemic, range, area, pl...
# 13    datum, model, base, method, estimate, survey, ...
# 14    distribution, region, endemic, range, area, pl...
# 15    distribution, region, endemic, range, area, pl...
# 16    community, ecosystem, soil, water, change, imp...
# 17    distribution, region, endemic, range, area, pl...
# 18    distribution, region, endemic, range, area, pl...
# 19    distribution, region, endemic, range, area, pl...
# 20    community, ecosystem, soil, water, change, imp...
# 21    distribution, region, endemic, range, area, pl...
# 22    distribution, region, endemic, range, area, pl...
# 23    datum, model, base, method, estimate, survey, ...
# 24    distribution, region, endemic, range, area, pl...
# 25    distribution, region, endemic, range, area, pl...
# 26    distribution, region, endemic, range, area, pl...
# 27    population, native, plant, decline, island, im...
# 28    distribution, region, endemic, range, area, pl...
# 29    distribution, region, endemic, range, area, pl...
# ...                                                 ...
# 4703  population, native, plant, decline, island, im...
# 4704  forest, tree, stand, tropical, disturbance, de...
# 4705  vegetation, plant, site, richness, community, ...
# 4706  vegetation, plant, site, richness, community, ...
# 4707  biodiversity, conservation, research, ecologic...
# 4708  biodiversity, conservation, research, ecologic...
# 4709  vegetation, plant, site, richness, community, ...
# 4710  vegetation, plant, site, richness, community, ...
# 4711  diversity, richness, group, pattern, genetic, ...
# 4712  biodiversity, conservation, research, ecologic...
# 4713  community, ecosystem, soil, water, change, imp...
# 4714  diversity, richness, group, pattern, genetic, ...
# 4715  community, ecosystem, soil, water, change, imp...
# 4716  biodiversity, conservation, research, ecologic...
# 4717  community, ecosystem, soil, water, change, imp...
# 4718  biodiversity, conservation, research, ecologic...
# 4719  diversity, richness, group, pattern, genetic, ...
# 4720  vegetation, plant, site, richness, community, ...
# 4721  vegetation, plant, site, richness, community, ...
# 4722  vegetation, plant, site, richness, community, ...
# 4723  community, ecosystem, soil, water, change, imp...
# 4724  biodiversity, conservation, research, ecologic...
# 4725  distribution, region, endemic, range, area, pl...
# 4726  local, management, resource, human, wildlife, ...
# 4727  population, native, plant, decline, island, im...
# 4728  vegetation, plant, site, richness, community, ...
# 4729  community, ecosystem, soil, water, change, imp...
# 4730  population, native, plant, decline, island, im...
# 4731  distribution, region, endemic, range, area, pl...
# 4732  biodiversity, conservation, research, ecologic...
#
#                                                    Text
# 0     [Abstract: 'Maintenance of soil health is cent...
# 1     [Abstract: 'Plant invasion is highly responsiv...
# 2     [Abstract: 'Globally, treeline in mountain lan...
# 3     [Abstract: 'Forests play a crucial role by reg...
# 4     [Abstract: 'The analysis of species distributi...
# 5     [Abstract: 'The Himalayan ecosystem is one of ...
# 6     [Abstract: 'In an era of climate change, predi...
# 7     [Abstract: 'The relationship and its key predi...
# 8     [Abstract: 'Climate change effects on Himalaya...
# 9     [Abstract: 'With the threats of climate change...
# 10    [Abstract: 'The variation hypothesis assumes s...
# 11    [Abstract: 'The evolutionary success of a spec...
# 12    [Abstract: 'The current study focuses on the i...
# 13    [Abstract: 'The objective of this research is ...
# 14    [Abstract: 'Global warming is causing shifts i...
# 15    [Abstract: 'The geographical patterns of speci...
# 16    [Abstract: 'Himalaya is endowed with a great d...
# 17    [Abstract: 'Globally, the increase in the clim...
# 18    [Abstract: 'Climate change enhances invasive s...
# 19    [Abstract: 'This study adopts a twofold strate...
# 20    [Abstract: 'Maintenance of soil health is cent...
# 21    [Abstract: 'Plant invasion is highly responsiv...
# 22    [Abstract: 'Globally, treeline in mountain lan...
# 23    [Abstract: 'Forests play a crucial role by reg...
# 24    [Abstract: 'The analysis of species distributi...
# 25    [Abstract: 'The Himalayan ecosystem is one of ...
# 26    [Abstract: 'In an era of climate change, predi...
# 27    [Abstract: 'The relationship and its key predi...
# 28    [Abstract: 'Climate change effects on Himalaya...
# 29    [Abstract: 'With the threats of climate change...
# ...                                                 ...
# 4703  [Abstract: 'The ability of trees to migrate in...
# 4704  [Abstract: 'The soil Coleoptera community was ...
# 4705                 [Abstract: Abstract not available]
# 4706                 [Abstract: Abstract not available]
# 4707  [Abstract: 'The species concept is applicable ...
# 4708  [Abstract: "Concluding remarks from the joint ...
# 4709                 [Abstract: Abstract not available]
# 4710                 [Abstract: Abstract not available]
# 4711  [Abstract: 'Diversities in fungi are manifold....
# 4712  [Abstract: 'In the framework of initiatives, a...
# 4713  [Abstract: 'A short overview of the biodiversi...
# 4714  [Abstract: 'Nucleic acid probes have revolutio...
# 4715  [Abstract: "Algae are ubiquitous. They are the...
# 4716  [Abstract: 'Global biodiversity in lichens is ...
# 4717  [Abstract: 'The unicellular eukaryotes are cur...
# 4718  [Abstract: 'An introduction to, and the Action...
# 4719  [Abstract: 'The distribution of rhizobia, bact...
# 4720                 [Abstract: Abstract not available]
# 4721                 [Abstract: Abstract not available]
# 4722                 [Abstract: Abstract not available]
# 4723  [Abstract: "From 1985 through 1990, the herpet...
# 4724  [Abstract: "Europe's five species ofMaculinea ...
# 4725  [Abstract: 'The montane (low- to mid-alpine) z...
# 4726  [Abstract: 'The economic viability of the wild...
# 4727  [Abstract: "On the basis of botanical and ecol...
# 4728                 [Abstract: Abstract not available]
# 4729  [Abstract: 'Biodiversity is undisturbed rhithr...
# 4730  [Abstract: 'Given the widespread belief that t...
# 4731  [Abstract: 'Heathlands, dominated byCalluna vu...
# 4732  [Abstract: 'Sandeels, especiallyAmmodytes mari...
#
# [4733 rows x 5 columns]

# %% [markdown]
# Saving the ```dataframe``` to disc for analysis.

# %%
df_dominant_topic.to_csv(session_folder_name+'/Master_Topic_Per_Centence.csv')

# %% [markdown]
# Here we find the most representative document for each topic, and contain it in a ```dataframe``` and save it as a ```.csv```

# %%
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], axis=0)

# %%
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]
sent_topics_sorteddf_mallet.head()
sent_topics_sorteddf_mallet.to_csv(session_folder_name+'/Master_Topics_Contribution.csv')

# %% [markdown]
# Here, we find the number of documents for each topic.

# %%
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# %% [markdown]
# Here, we find the percentage of documents falling under each topic.

# %%
topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# %% [markdown]
# Presenting the dominant topics in each sentence here.

# %%
df_dominant_topics
# Out:
#       Dominant_Topic                                     Topic_Keywords  \
# 0                4.0  community, ecosystem, soil, water, change, imp...
# 1                9.0  distribution, region, endemic, range, area, pl...
# 2                9.0  distribution, region, endemic, range, area, pl...
# 3                3.0  datum, model, base, method, estimate, survey, ...
# 4                9.0  distribution, region, endemic, range, area, pl...
# 5                9.0  distribution, region, endemic, range, area, pl...
# 6                9.0  distribution, region, endemic, range, area, pl...
# 7                6.0  population, native, plant, decline, island, im...
# 8                9.0  distribution, region, endemic, range, area, pl...
# 9                9.0  distribution, region, endemic, range, area, pl...
# 10               3.0  datum, model, base, method, estimate, survey, ...
# 11              11.0  biodiversity, conservation, research, ecologic...
# 12               9.0  distribution, region, endemic, range, area, pl...
# 13               3.0  datum, model, base, method, estimate, survey, ...
# 14               9.0  distribution, region, endemic, range, area, pl...
# 15               9.0  distribution, region, endemic, range, area, pl...
# 16               4.0  community, ecosystem, soil, water, change, imp...
# 17               9.0  distribution, region, endemic, range, area, pl...
# 18               9.0  distribution, region, endemic, range, area, pl...
# 19               9.0  distribution, region, endemic, range, area, pl...
# 20               4.0  community, ecosystem, soil, water, change, imp...
# 21               9.0  distribution, region, endemic, range, area, pl...
# 22               9.0  distribution, region, endemic, range, area, pl...
# 23               3.0  datum, model, base, method, estimate, survey, ...
# 24               9.0  distribution, region, endemic, range, area, pl...
# 25               9.0  distribution, region, endemic, range, area, pl...
# 26               9.0  distribution, region, endemic, range, area, pl...
# 27               6.0  population, native, plant, decline, island, im...
# 28               9.0  distribution, region, endemic, range, area, pl...
# 29               9.0  distribution, region, endemic, range, area, pl...
# ...              ...                                                ...
# 4703             6.0  population, native, plant, decline, island, im...
# 4704             7.0  forest, tree, stand, tropical, disturbance, de...
# 4705             0.0  vegetation, plant, site, richness, community, ...
# 4706             0.0  vegetation, plant, site, richness, community, ...
# 4707            11.0  biodiversity, conservation, research, ecologic...
# 4708            11.0  biodiversity, conservation, research, ecologic...
# 4709             0.0  vegetation, plant, site, richness, community, ...
# 4710             0.0  vegetation, plant, site, richness, community, ...
# 4711            10.0  diversity, richness, group, pattern, genetic, ...
# 4712            11.0  biodiversity, conservation, research, ecologic...
# 4713             4.0  community, ecosystem, soil, water, change, imp...
# 4714            10.0  diversity, richness, group, pattern, genetic, ...
# 4715             4.0  community, ecosystem, soil, water, change, imp...
# 4716            11.0  biodiversity, conservation, research, ecologic...
# 4717             4.0  community, ecosystem, soil, water, change, imp...
# 4718            11.0  biodiversity, conservation, research, ecologic...
# 4719            10.0  diversity, richness, group, pattern, genetic, ...
# 4720             0.0  vegetation, plant, site, richness, community, ...
# 4721             0.0  vegetation, plant, site, richness, community, ...
# 4722             0.0  vegetation, plant, site, richness, community, ...
# 4723             4.0  community, ecosystem, soil, water, change, imp...
# 4724            11.0  biodiversity, conservation, research, ecologic...
# 4725             9.0  distribution, region, endemic, range, area, pl...
# 4726             5.0  local, management, resource, human, wildlife, ...
# 4727             6.0  population, native, plant, decline, island, im...
# 4728             0.0  vegetation, plant, site, richness, community, ...
# 4729             4.0  community, ecosystem, soil, water, change, imp...
# 4730             6.0  population, native, plant, decline, island, im...
# 4731             9.0  distribution, region, endemic, range, area, pl...
# 4732            11.0  biodiversity, conservation, research, ecologic...
#
#       Num_Documents  Perc_Documents
# 0             690.0          0.1458
# 1             329.0          0.0695
# 2             320.0          0.0676
# 3             324.0          0.0685
# 4             367.0          0.0775
# 5             436.0          0.0921
# 6             334.0          0.0706
# 7             489.0          0.1033
# 8             323.0          0.0682
# 9             350.0          0.0739
# 10            299.0          0.0632
# 11            472.0          0.0997
# 12              NaN             NaN
# 13              NaN             NaN
# 14              NaN             NaN
# 15              NaN             NaN
# 16              NaN             NaN
# 17              NaN             NaN
# 18              NaN             NaN
# 19              NaN             NaN
# 20              NaN             NaN
# 21              NaN             NaN
# 22              NaN             NaN
# 23              NaN             NaN
# 24              NaN             NaN
# 25              NaN             NaN
# 26              NaN             NaN
# 27              NaN             NaN
# 28              NaN             NaN
# 29              NaN             NaN
# ...             ...             ...
# 4703            NaN             NaN
# 4704            NaN             NaN
# 4705            NaN             NaN
# 4706            NaN             NaN
# 4707            NaN             NaN
# 4708            NaN             NaN
# 4709            NaN             NaN
# 4710            NaN             NaN
# 4711            NaN             NaN
# 4712            NaN             NaN
# 4713            NaN             NaN
# 4714            NaN             NaN
# 4715            NaN             NaN
# 4716            NaN             NaN
# 4717            NaN             NaN
# 4718            NaN             NaN
# 4719            NaN             NaN
# 4720            NaN             NaN
# 4721            NaN             NaN
# 4722            NaN             NaN
# 4723            NaN             NaN
# 4724            NaN             NaN
# 4725            NaN             NaN
# 4726            NaN             NaN
# 4727            NaN             NaN
# 4728            NaN             NaN
# 4729            NaN             NaN
# 4730            NaN             NaN
# 4731            NaN             NaN
# 4732            NaN             NaN
#
# [4733 rows x 4 columns]

# %% [markdown]
# Saving it to a ```.csv``` bucket here.

# %%
df_dominant_topics.to_csv(session_folder_name+'/Master_Topics.csv')

# %% [markdown]
# Generating the visualization here from the ```lda_model```. We use this to label the broad areas of research, in syn which the representative documents generated above.

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
# Out:
# /home/sarthak/.local/lib/python3.5/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# Enabling the visualizations in the notebook here.

# %%
pyLDAvis.enable_notebook()

# %% [markdown]
# Saving the visualization to the disk, as an ```.html``` file in the sessions folder.

# %%
pyLDAvis.save_html(vis, session_folder_name+'/Master.html')

# %% [markdown]
# Presenting the ```pyLDAvis``` visualization here.

# %%
vis
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 11     37.817173        1       1 -0.317037  0.031738
# 4      31.456345        1       2 -0.297547  0.107870
# 10      8.202921        1       3 -0.204476 -0.055713
# 8       7.000277        1       4 -0.111004 -0.238273
# 3       5.913970        1       5 -0.097848  0.227758
# 6       2.851634        1       6 -0.001512 -0.232949
# 1       1.653463        1       7  0.148263  0.068872
# 9       1.638315        1       8  0.150440 -0.018081
# 5       1.173970        1       9  0.150620  0.053983
# 0       1.014442        1      10  0.185774  0.015144
# 7       0.663275        1      11  0.197799  0.018059
# 2       0.614215        1      12  0.196526  0.021592, topic_info=      Category         Freq            Term        Total  loglift  logprob
# 15674  Default  6696.000000          forest  6696.000000  30.0000  30.0000
# 8979   Default  3265.000000           plant  3265.000000  29.0000  29.0000
# 15607  Default  2826.000000      population  2826.000000  28.0000  28.0000
# 13274  Default  1942.000000            tree  1942.000000  27.0000  27.0000
# 4380   Default  5196.000000    conservation  5196.000000  26.0000  26.0000
# 1841   Default  3049.000000        richness  3049.000000  25.0000  25.0000
# 8008   Default  1030.000000            soil  1030.000000  24.0000  24.0000
# 23808  Default  1061.000000         endemic  1061.000000  23.0000  23.0000
# 10542  Default  1197.000000            bird  1197.000000  22.0000  22.0000
# 5882   Default  4824.000000         habitat  4824.000000  21.0000  21.0000
# 2430   Default  4765.000000       diversity  4765.000000  20.0000  20.0000
# 22728  Default  1629.000000    distribution  1629.000000  19.0000  19.0000
# 21374  Default   852.000000          island   852.000000  18.0000  18.0000
# 16448  Default  1031.000000            taxa  1031.000000  17.0000  17.0000
# 6380   Default  2217.000000            area  2217.000000  16.0000  16.0000
# 9057   Default  1560.000000          region  1560.000000  15.0000  15.0000
# 14643  Default  2767.000000          number  2767.000000  14.0000  14.0000
# 13173  Default  3750.000000    biodiversity  3750.000000  13.0000  13.0000
# 23177  Default   617.000000          native   617.000000  12.0000  12.0000
# 16803  Default  3193.000000            site  3193.000000  11.0000  11.0000
# 21007  Default  1527.000000          change  1527.000000  10.0000  10.0000
# 10905  Default   828.000000            rare   828.000000   9.0000   9.0000
# 19217  Default   841.000000         genetic   841.000000   8.0000   8.0000
# 1293   Default  1158.000000           model  1158.000000   7.0000   7.0000
# 7234   Default   761.000000            seed   761.000000   6.0000   6.0000
# 9398   Default  1475.000000           total  1475.000000   5.0000   5.0000
# 22673  Default   831.000000            plot   831.000000   4.0000   4.0000
# 1123   Default  1638.000000          sample  1638.000000   3.0000   3.0000
# 14505  Default  1155.000000           range  1155.000000   2.0000   2.0000
# 12033  Default  1459.000000         pattern  1459.000000   1.0000   1.0000
# ...        ...          ...             ...          ...      ...      ...
# 12593  Topic12    69.405220   concentration    70.590538   5.0756  -3.7949
# 12871  Topic12    57.891911    semi_natural    59.077209   5.0723  -3.9763
# 3699   Topic12    45.515293        adoption    46.700695   5.0669  -4.2168
# 13498  Topic12    40.166451     competition    41.351749   5.0635  -4.3419
# 21478  Topic12    37.235420           sheep    38.420746   5.0612  -4.4176
# 19371  Topic12    35.814816      pollinator    37.000103   5.0600  -4.4565
# 7535   Topic12    35.456909             bee    36.642227   5.0597  -4.4666
# 186    Topic12    31.337463     pollination    32.522755   5.0555  -4.5901
# 15947  Topic12    29.019400        constant    30.204737   5.0525  -4.6669
# 6158   Topic12    27.772173     predominant    28.957518   5.0508  -4.7109
# 23357  Topic12    22.861277       technical    24.046589   5.0420  -4.9054
# 3915   Topic12    21.893812          floral    23.079111   5.0399  -4.9487
# 21718  Topic12    16.375957  methodological    17.561260   5.0227  -5.2391
# 14709  Topic12    16.270903       pollinate    17.456215   5.0223  -5.2455
# 1527   Topic12    14.378037     hymenoptera    15.563348   5.0134  -5.3692
# 12436  Topic12    14.108826          greece    15.294121   5.0119  -5.3881
# 11613  Topic12    14.048531           error    15.233821   5.0116  -5.3924
# 20677  Topic12    13.074234            sell    14.259541   5.0058  -5.4642
# 6433   Topic12    12.972056              fd    14.157461   5.0051  -5.4721
# 3276   Topic12    12.437304            load    13.622599   5.0016  -5.5142
# 8609   Topic12    10.880110      visitation    12.065401   4.9892  -5.6480
# 2279   Topic12     9.782307        honeybee    10.967595   4.9782  -5.7543
# 19097  Topic12     6.834234      phosphorus     8.019540   4.9326  -6.1129
# 4025   Topic12     6.203062         version     7.388359   4.9177  -6.2098
# 67     Topic12     5.653595      competitor     6.838904   4.9022  -6.3026
# 9762   Topic12     4.627139        internet     5.812431   4.8645  -6.5029
# 10119  Topic12    40.050938     fluctuation    74.648270   4.4699  -4.3447
# 5752   Topic12    41.128056           trait   114.472183   4.0689  -4.3182
# 392    Topic12    38.856705    reproductive   107.068443   4.0790  -4.3750
# 21347  Topic12     7.373934            hand   136.367661   2.1752  -6.0369
#
# [576 rows x 6 columns], token_table=       Topic      Freq           Term
# term
# 18779      8  0.982472         absent
# 5274       1  0.972637      abundance
# 5274       5  0.026770      abundance
# 12722      1  0.995856       abundant
# 11251      8  0.971644         acacia
# 11072      9  0.979952      accession
# 10150      7  0.980604      accompany
# 9676       9  0.982864           acid
# 18691      2  0.995435         action
# 9368       1  0.203628       activity
# 9368       2  0.501347       activity
# 9368       5  0.292101       activity
# 10538      7  0.989595     adaptation
# 3699      12  0.984996       adoption
# 3338       7  0.983523        advance
# 3723      11  0.990440          algae
# 23145     11  0.986644          algal
# 17174      8  0.990937          alien
# 13582      4  0.992380         alpine
# 9122       4  0.546196       altitude
# 9122       6  0.446888       altitude
# 12117      4  0.991189       amazonia
# 8936       4  0.996036      amazonian
# 18441      6  0.975973     angiosperm
# 16276      1  0.104365         animal
# 16276      2  0.533686         animal
# 16276      5  0.360534         animal
# 6988       1  0.282911         annual
# 6988       3  0.111016         annual
# 6988       4  0.164733         annual
# ...      ...       ...            ...
# 8609      12  0.911698     visitation
# 1736       2  0.237372  vulnerability
# 1736       7  0.753042  vulnerability
# 3312       1  0.521232          water
# 3312       3  0.272462          water
# 3312       5  0.104641          water
# 3312       9  0.100693          water
# 7469       8  0.977025           weed
# 3430       6  0.968624    west_africa
# 4840       5  0.997500        wetland
# 18908      3  0.703118           wild
# 18908      8  0.160925           wild
# 18908      9  0.136167           wild
# 2919       2  0.276926       wildlife
# 2919       5  0.720911       wildlife
# 16553      3  0.989495         winter
# 1174       1  0.996380           wood
# 17467      1  0.998785       woodland
# 20231      6  0.689644          woody
# 20231      8  0.305414          woody
# 8063       2  0.997553          world
# 14151      1  0.272461           year
# 14151      2  0.068359           year
# 14151      3  0.063477           year
# 14151      4  0.119141           year
# 14151      5  0.477540           year
# 21430      1  0.629380           zone
# 21430      2  0.016815           zone
# 21430      4  0.103295           zone
# 21430      6  0.247428           zone
#
# [806 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'ylab': 'PC2', 'xlab': 'PC1'}, topic_order=[12, 5, 11, 9, 4, 7, 2, 10, 6, 1, 8, 3])

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab8',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = optimal_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 8, figsize=(100, 100), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i+1), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
